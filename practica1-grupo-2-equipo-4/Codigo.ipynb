# %% [markdown]
# # Practica 1
# ## Equipo 4

# %% [markdown]
# ## Sistema de Lógica Difusa

# %% [markdown]
# ### Configuración Inicial

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %% [markdown]
# ### Definición de variables y conjuntos difusos

# %% [markdown]
# En esta sección, estamos definiendo las **variables difusas** que serán utilizadas en el sistema de lógica difusa para evaluar el **riesgo de impago** de una persona. Estas variables se dividen en:
#
# 1. **Antecedentes**:
#    - **Ingreso mensual**: Representa el nivel de ingresos de una persona, con un rango de 0 a 10 millones de pesos.
#    - **Estabilidad laboral**: Representa la estabilidad laboral de una persona, con un rango de 0 a 10 en una escala subjetiva.
#    - **Puntaje crediticio**: Representa el puntaje crediticio de una persona, con un rango de 0 a 1000, basado en estándares financieros.
#
# 2. **Consecuente**:
#    - **Riesgo de impago**: Representa el nivel de riesgo de que una persona no cumpla con sus obligaciones financieras, con un rango de 0 a 100 (porcentaje).

# %%
def definicion_conjuntos_difusos():
    """
    Define los antecedentes y el consecuente del sistema difuso.

    Retorna:
        dict: Diccionario con pares nombre: objeto de los conjuntos difusos.
    """
    # Antecedentes
    ingreso_mensual = ctrl.Antecedent(np.arange(0, 10.1, 0.1), 'ingreso_mensual')
    estabilidad_laboral = ctrl.Antecedent(np.arange(0, 10.1, 0.1), 'estabilidad_laboral')
    puntaje_crediticio = ctrl.Antecedent(np.arange(0, 1001, 1), 'puntaje_crediticio')

    # Consecuente
    riesgo_impago = ctrl.Consequent(np.arange(0, 101, 1), 'riesgo_impago')

    # Retornar los conjuntos difusos en un diccionario
    return {
        "ingreso_mensual": ingreso_mensual,
        "estabilidad_laboral": estabilidad_laboral,
        "puntaje_crediticio": puntaje_crediticio,
        "riesgo_impago": riesgo_impago
    }

# %% [markdown]
# A continuación, se definen las **funciones de pertenencia** para las variables difusas previamente declaradas. Estas funciones permiten modelar los valores lingüísticos asociados a cada variable, como "bajo", "medio", "alto", entre otros, utilizando diferentes formas matemáticas (trapezoidal, triangular, gaussiana, etc.).
#
# **Detalles**:
# 1. **Ingreso mensual**:
#    - Valores lingüísticos: "bajo", "medio", "alto".
#    - Modificadores: "más o menos alto", "extremadamente alto".
#
# 2. **Estabilidad laboral**:
#    - Valores lingüísticos: "inestable", "moderada", "estable".
#    - Modificadores: "muy estable", "más o menos estable".
#
# 3. **Puntaje crediticio**:
#    - Valores lingüísticos: "malo", "regular", "bueno".
#    - Modificadores: "muy bueno", "más o menos malo".
#
# 4. **Riesgo de impago**:
#    - Valores lingüísticos: "bajo", "medio", "alto".
#    - Modificadores: "muy bajo", "más o menos alto".

# %%
def funciones_pertenencia(ingreso_mensual, estabilidad_laboral, puntaje_crediticio, riesgo_impago):
    # Ingreso mensual
    ingreso_mensual['bajo'] = fuzz.trapmf(ingreso_mensual.universe, [0, 0, 1.4, 2.8])
    ingreso_mensual['medio'] = fuzz.trimf(ingreso_mensual.universe, [1.4, 3, 5.5])
    ingreso_mensual['alto'] = fuzz.gaussmf(ingreso_mensual.universe, 10, 2.8)

    # Modificadores para ingreso mensual
    ingreso_mensual['mas o menos alto'] = np.sqrt(fuzz.gaussmf(ingreso_mensual.universe, 10, 2.8))
    ingreso_mensual['extremadamente alto'] = np.power(fuzz.gaussmf(ingreso_mensual.universe, 10, 2.8), 3)

    # Estabilidad laboral
    estabilidad_laboral['inestable'] = fuzz.trapmf(estabilidad_laboral.universe, [0, 0, 2, 4])
    estabilidad_laboral['moderada'] = fuzz.trimf(estabilidad_laboral.universe, [3, 5.5, 7])
    estabilidad_laboral['estable'] = fuzz.gaussmf(estabilidad_laboral.universe, 10, 2.5)

    # Modificadores para estabilidad laboral
    estabilidad_laboral['muy estable'] = np.power(fuzz.gaussmf(estabilidad_laboral.universe, 10, 2.5), 2)
    estabilidad_laboral['mas o menos estable'] = np.sqrt(fuzz.gaussmf(estabilidad_laboral.universe, 10, 2.5))

    # Puntaje crediticio
    puntaje_crediticio['malo'] = fuzz.trimf(puntaje_crediticio.universe, [0, 0, 500])
    puntaje_crediticio['regular'] = fuzz.gaussmf(puntaje_crediticio.universe, 500, 150)
    puntaje_crediticio['bueno'] = fuzz.trapmf(puntaje_crediticio.universe, [600, 720, 1000, 1000])

    # Modificadores para puntaje crediticio
    puntaje_crediticio['muy bueno'] = np.power(fuzz.trapmf(puntaje_crediticio.universe, [600, 800, 1000, 1000]), 2)
    puntaje_crediticio['mas o menos malo'] = np.sqrt(fuzz.trimf(puntaje_crediticio.universe, [0, 250, 450]))

    # Riesgo de impago
    riesgo_impago['bajo'] = fuzz.trimf(riesgo_impago.universe, [0, 0, 35])
    riesgo_impago['medio'] = fuzz.trapmf(riesgo_impago.universe, [20, 40, 60, 80])
    riesgo_impago['alto'] = fuzz.gaussmf(riesgo_impago.universe, 100, 25)

    # Modificadores para riesgo de impago
    riesgo_impago['muy bajo'] = np.power(fuzz.trimf(riesgo_impago.universe, [0, 0, 35]), 2)
    riesgo_impago['mas o menos alto'] = np.sqrt(fuzz.gaussmf(riesgo_impago.universe, 100, 25))

    return {
        "ingreso_mensual": ingreso_mensual,
        "estabilidad_laboral": estabilidad_laboral,
        "puntaje_crediticio": puntaje_crediticio,
        "riesgo_impago": riesgo_impago
    }

# %% [markdown]
# ### Definición de reglas difusas

# %% [markdown]
# En esta sección, se definen las reglas difusas que serán utilizadas para evaluar el **riesgo de impago** de una persona, basándose en las variables de entrada: **ingreso mensual**, **estabilidad laboral** y **puntaje crediticio**.

# %%
def reglas(ingreso_mensual, estabilidad_laboral, puntaje_crediticio, riesgo_impago):
    # Regla 1: Si el ingreso es bajo y el puntaje es malo, entonces el riesgo es alto.
    regla1 = ctrl.Rule(
        ingreso_mensual['bajo'] & puntaje_crediticio['malo'],
        riesgo_impago['alto']
    )

    # Regla 2: Si el ingreso es medio o la estabilidad es moderada y el puntaje es regular, entonces riesgo medio.
    regla2 = ctrl.Rule(
        (ingreso_mensual['medio'] | estabilidad_laboral['moderada']) & puntaje_crediticio['regular'],
        riesgo_impago['medio']
    )

    # Regla 3: Si el ingreso es alto o el puntaje es bueno, entonces el riesgo es bajo.
    regla3 = ctrl.Rule(
        ingreso_mensual['alto'] | puntaje_crediticio['bueno'],
        riesgo_impago['bajo']
    )

    # Regla 4: Si el ingreso no es alto y la estabilidad es inestable, entonces el riesgo es más o menos alto.
    regla4 = ctrl.Rule(
        ~ingreso_mensual['alto'] & estabilidad_laboral['inestable'],
        riesgo_impago['mas o menos alto']
    )

    # Regla 5: Si el ingreso es bajo o el puntaje no es bueno, entonces el riesgo es mas o menos alto.
    regla5 = ctrl.Rule(
        ingreso_mensual['bajo'] | ~puntaje_crediticio['bueno'],
        riesgo_impago['mas o menos alto']
    )

    # Regla 6: Si el ingreso es medio y el puntaje es regular, el riesgo es medio.
    regla6 = ctrl.Rule(
        ingreso_mensual['medio'] & puntaje_crediticio['regular'],
        riesgo_impago['medio']
    )

    # Regla 7: Si la estabilidad es muy estable y el puntaje no es malo, el riesgo es bajo.
    regla7 = ctrl.Rule(
        estabilidad_laboral['muy estable'] & ~puntaje_crediticio['malo'],
        riesgo_impago['bajo']
    )

    # Regla 8: Si la estabilidad es inestable y el puntaje es malo, el riesgo es alto.
    regla8 = ctrl.Rule(
        estabilidad_laboral['inestable'] & puntaje_crediticio['malo'],
        riesgo_impago['alto']
    )

    # Regla 9: Si el ingreso es medio y el puntaje es bueno, el riesgo es bajo.
    regla9 = ctrl.Rule(
        ingreso_mensual['medio'] & puntaje_crediticio['bueno'],
        riesgo_impago['bajo']
    )

    return [
        regla1, regla2, regla3, regla4, 
        regla5, regla6, regla7, regla8, regla9
    ]

# %% [markdown]
# ### Defuzzificación

# %%
def motor(reglas : list, valores : dict):
    # Agregar todas las reglas al sistema de control difuso
    sistema_control = ctrl.ControlSystem(reglas)

    # Importar el módulo de simulación del sistema de control difuso
    sistema_simulacion = ctrl.ControlSystemSimulation(sistema_control)

    # Asignar valores a las variables de entrada del sistema difuso
    sistema_simulacion.input['ingreso_mensual'] = valores['ingreso_mensual']           # En millones de pesos (escala 0 a 10)
    sistema_simulacion.input['estabilidad_laboral'] = valores['estabilidad_laboral']          # Escala de estabilidad (0 a 10)
    sistema_simulacion.input['puntaje_crediticio'] = valores['puntaje_crediticio']         # Puntaje crediticio (escala 0 a 1000)

    # Ejecutar el motor de inferencia difusa
    sistema_simulacion.compute()

    # Obtener el valor defuzzificado de la variable de salida "riesgo_impago"
    # Por defecto, se utiliza el método del centroide (centroid), que calcula el centro de gravedad
    riesgo_impago_defuzzificado = sistema_simulacion.output['riesgo_impago']

    # Mostrar el resultado final como un valor numérico preciso (crisp)
    # Este valor resume la evaluación difusa en una única cifra entre 0 y 100
    print(f"El riesgo de impago defuzzificado es: {riesgo_impago_defuzzificado:.2f}")

    return riesgo_impago_defuzzificado

# %% [markdown]
# ### Sistema difuso completo

# %%
def sistema_difuso(ingreso_mensual, estabilidad_laboral, puntaje_crediticio):
    """
    Calcula el riesgo de impago utilizando un sistema difuso.

    Args:
        ingreso_mensual (float): Nivel de ingreso mensual (0 a 10).
        puntaje_crediticio (int): Puntaje crediticio (0 a 1000).
        estabilidad_laboral (float): Nivel de estabilidad laboral (0 a 10).

    Returns:
        float: Valor defuzzificado del riesgo de impago.
    """
    # Definir los conjuntos difusos
    conjuntos_difusos = definicion_conjuntos_difusos()

    # Definir las funciones de pertenencia
    conjuntos_difusos = funciones_pertenencia(**conjuntos_difusos)

    # Definir las reglas difusas
    reglas_difusas = reglas(**conjuntos_difusos)

    # Crear el diccionario de valores de entrada
    valores_entrada = {
        'ingreso_mensual': ingreso_mensual,
        'estabilidad_laboral': estabilidad_laboral,
        'puntaje_crediticio': puntaje_crediticio
    }

    # Ejecutar el motor difuso
    resultado = motor(reglas_difusas, valores_entrada)

    return resultado

# %%
sistema_difuso(1,1,700)
# Out:
# El riesgo de impago defuzzificado es: 56.71
# np.float64(56.71017276084723)

# %% [markdown]
# ## Ontología y Razonamiento Semántico

# %% [markdown]
# ### Configuración Inicial
# Instalamos las librerías y preparamos el programa.

# %%
# %pip install rdflib owlrl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rdflib in c:\users\d0ubt\appdata\roaming\python\python313\site-packages (7.1.4)
# Requirement already satisfied: owlrl in c:\users\d0ubt\appdata\roaming\python\python313\site-packages (7.1.3)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\d0ubt\appdata\roaming\python\python313\site-packages (from rdflib) (3.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, FOAF, DC, XSD


# Crear grafo
g = Graph()

# Namespaces
EX = Namespace("http://practica1.org/evaluacion_creditos#")
g.bind("ex", EX)
g.bind("foaf", FOAF)
g.bind("rdfs", RDFS)

# %% [markdown]
# ### Creación de Clases

# %%
# Persona y sus subclases
g.add((EX.Persona, RDF.type, RDFS.Class))

g.add((EX.Estudiante, RDF.type, RDFS.Class))
g.add((EX.Estudiante, RDFS.subClassOf, EX.Persona))

g.add((EX.Jubilado, RDF.type, RDFS.Class))
g.add((EX.Jubilado, RDFS.subClassOf, EX.Persona))

g.add((EX.Empleado, RDF.type, RDFS.Class))
g.add((EX.Empleado, RDFS.subClassOf, EX.Persona))

g.add((EX.Independiente, RDF.type, RDFS.Class))
g.add((EX.Independiente, RDFS.subClassOf, EX.Persona))

# Ingreso y sus subclases
g.add((EX.Ingreso, RDF.type, RDFS.Class))

g.add((EX.IngresoFijo, RDF.type, RDFS.Class))
g.add((EX.IngresoFijo, RDFS.subClassOf, EX.Ingreso))

g.add((EX.IngresoVariable, RDF.type, RDFS.Class))
g.add((EX.IngresoVariable, RDFS.subClassOf, EX.Ingreso))

# Crédito y sus subclases
g.add((EX.Credito, RDF.type, RDFS.Class))

g.add((EX.LibreInversion, RDF.type, RDFS.Class))
g.add((EX.LibreInversion, RDFS.subClassOf, EX.Credito))

g.add((EX.CreditoHipotecario, RDF.type, RDFS.Class))
g.add((EX.CreditoHipotecario, RDFS.subClassOf, EX.Credito))

g.add((EX.CreditoVehicular, RDF.type, RDFS.Class))
g.add((EX.CreditoVehicular, RDFS.subClassOf, EX.Credito))

# Historial y sus subclases
g.add((EX.Historial, RDF.type, RDFS.Class))

g.add((EX.PuntajeCrediticio, RDF.type, RDFS.Class))
g.add((EX.PuntajeCrediticio, RDFS.subClassOf, EX.Historial))

g.add((EX.CapacidadEndeudamiento, RDF.type, RDFS.Class))
g.add((EX.CapacidadEndeudamiento, RDFS.subClassOf, EX.Historial))

# --------- SERIALIZAR PARA VER RESULTADO ----------

print(g.serialize(format="turtle"))
# Out:
# @prefix ex: <http://practica1.org/evaluacion_creditos#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# ex:CapacidadEndeudamiento a rdfs:Class ;
#     rdfs:subClassOf ex:Historial .
#
# ex:Credito a rdfs:Class .
#
# ex:CreditoHipotecario a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:CreditoVehicular a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:Empleado a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Estudiante a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Historial a rdfs:Class .
#
# ex:Independiente a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Ingreso a rdfs:Class .
#
# ex:IngresoFijo a rdfs:Class ;
#     rdfs:subClassOf ex:Ingreso .
#
# ex:IngresoVariable a rdfs:Class ;
#     rdfs:subClassOf ex:Ingreso .
#
# ex:Jubilado a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:LibreInversion a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:Persona a rdfs:Class .
#
# ex:PuntajeCrediticio a rdfs:Class ;
#     rdfs:subClassOf ex:Historial .

# %% [markdown]
# ### Creación de Propiedades

# %%
# ------------ PROPIEDADES ------------

# foaf:name (nombre de la persona)



g.add((FOAF.name, RDF.type, RDF.Property))
g.add((FOAF.name, RDFS.domain, EX.Persona))
g.add((FOAF.name, RDFS.range, XSD.string))

# ex:anioNacimiento
g.add((EX.anioNacimiento, RDF.type, RDF.Property))
g.add((EX.anioNacimiento, RDFS.domain, EX.Persona))
g.add((EX.anioNacimiento, RDFS.range, XSD.gYear))

# ex:tieneIngreso
g.add((EX.tieneIngreso, RDF.type, RDF.Property))
g.add((EX.tieneIngreso, RDFS.domain, EX.Persona))
g.add((EX.tieneIngreso, RDFS.range, EX.Ingreso))

# foaf:knows (Para que aparezca en el grafo)
g.add((FOAF.knows, RDF.type, RDF.Property))
g.add((FOAF.knows, RDFS.domain, EX.Persona))
g.add((FOAF.knows, RDFS.range, EX.Persona))

# ex:referido (subproperty of foaf:knows)
g.add((EX.referido, RDF.type, RDF.Property))
g.add((EX.referido, RDFS.subPropertyOf, FOAF.knows))
g.add((EX.referido, RDFS.domain, EX.Persona))
g.add((EX.referido, RDFS.range, EX.Persona))

# ex:coSolicitante (subproperty of foaf:knows)
g.add((EX.coSolicitante, RDF.type, RDF.Property))
g.add((EX.coSolicitante, RDFS.subPropertyOf, FOAF.knows))
g.add((EX.coSolicitante, RDFS.domain, EX.Persona))
g.add((EX.coSolicitante, RDFS.range, EX.Persona))

# ex:TieneCredito
g.add((EX.tieneCredito, RDF.type, RDF.Property))
g.add((EX.tieneCredito, RDFS.domain, EX.Persona))
g.add((EX.tieneCredito, RDFS.range, EX.Credito))

# ex:tieneHistorial
g.add((EX.tieneHistorial, RDF.type, RDF.Property))
g.add((EX.tieneHistorial, RDFS.domain, EX.Persona))
g.add((EX.tieneHistorial, RDFS.range, EX.Historial))

# ex:estabilidadLaboral
g.add((EX.estabilidadLaboral, RDF.type, RDF.Property))
g.add((EX.estabilidadLaboral, RDFS.domain, EX.Persona))  # Nota: aquí es para Empleado o Independiente
g.add((EX.estabilidadLaboral, RDFS.range, XSD.string))

# ex:montoIngreso
g.add((EX.montoIngreso, RDF.type, RDF.Property))
g.add((EX.montoIngreso, RDFS.domain, EX.Ingreso))
g.add((EX.montoIngreso, RDFS.range, XSD.decimal))

# ex:monto (propiedad general)
g.add((EX.monto, RDF.type, RDF.Property))
g.add((EX.monto, RDFS.domain, EX.Credito))
g.add((EX.monto, RDFS.range, XSD.decimal))

# ex:montoSolicitado (subproperty of ex:monto)
g.add((EX.montoSolicitado, RDF.type, RDF.Property))
g.add((EX.montoSolicitado, RDFS.subPropertyOf, EX.monto))
g.add((EX.montoSolicitado, RDFS.domain, EX.Credito))
g.add((EX.montoSolicitado, RDFS.range, XSD.decimal))

# ex:montoAprobado (subproperty of ex:monto)
g.add((EX.montoAprobado, RDF.type, RDF.Property))
g.add((EX.montoAprobado, RDFS.subPropertyOf, EX.monto))
g.add((EX.montoAprobado, RDFS.domain, EX.Credito))
g.add((EX.montoAprobado, RDFS.range, XSD.decimal))

# ex:plazo
g.add((EX.plazo, RDF.type, RDF.Property))
g.add((EX.plazo, RDFS.domain, EX.Credito))
g.add((EX.plazo, RDFS.range, XSD.integer))

# ex:puntajeCrediticio
g.add((EX.puntajeCrediticio, RDF.type, RDF.Property))
g.add((EX.puntajeCrediticio, RDFS.domain, EX.Historial))
g.add((EX.puntajeCrediticio, RDFS.range, XSD.decimal))

# ex:capacidadEndeudamiento
g.add((EX.capacidadEndeudamiento, RDF.type, RDF.Property))
g.add((EX.capacidadEndeudamiento, RDFS.domain, EX.Historial))
g.add((EX.capacidadEndeudamiento, RDFS.range, XSD.decimal))

# ex:estadoCredito
g.add((EX.estadoCredito, RDF.type, RDF.Property))
g.add((EX.estadoCredito, RDFS.domain, EX.Credito))
g.add((EX.estadoCredito, RDFS.range, XSD.string))

# dc:identifier
g.add((DC.identifier, RDF.type, RDF.Property))
g.add((DC.identifier, RDFS.domain, EX.Credito))
g.add((DC.identifier, RDFS.range, XSD.string))

# ------------ SERIALIZAR PARA VER RESULTADO ------------
# print(g.serialize(format="turtle"))
# Out:
# <Graph identifier=Ndfdfd8c4a8184e559eb6cd48abef97c8 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### Instancias

# %%
# 1️⃣ Personas y subclases
persona1 = URIRef(EX.Persona3654)
persona2 = URIRef(EX.Persona6798)
persona3 = URIRef(EX.Persona786)
persona4 = URIRef(EX.Persona221)

g.add((persona1, RDF.type, EX.Persona))
g.add((persona2, RDF.type, EX.Persona))
g.add((persona3, RDF.type, EX.Persona))
g.add((persona4, RDF.type, EX.Persona))

# Estudiantes
estudiante1 = URIRef(EX.Freddy) #
estudiante2 = URIRef(EX.Jose) #
estudiante3 = URIRef(EX.Camila) #
estudiante4 = URIRef(EX.Jeremias) #

g.add((estudiante1, RDF.type, EX.Estudiante))
g.add((estudiante2, RDF.type, EX.Estudiante))
g.add((estudiante3, RDF.type, EX.Estudiante))
g.add((estudiante4, RDF.type, EX.Estudiante))

# Jubilados
jubilado1 = URIRef(EX.Rosa) #
jubilado2 = URIRef(EX.Manuel) #
jubilado3 = URIRef(EX.Lucia) #
jubilado4 = URIRef(EX.Carlos) #

g.add((jubilado1, RDF.type, EX.Jubilado))
g.add((jubilado2, RDF.type, EX.Jubilado))
g.add((jubilado3, RDF.type, EX.Jubilado))
g.add((jubilado4, RDF.type, EX.Jubilado))

# Empleados
empleado1 = URIRef(EX.Maria) #
empleado2 = URIRef(EX.Alejandro) #
empleado3 = URIRef(EX.Diana) #
empleado4 = URIRef(EX.Pedro) #

g.add((empleado1, RDF.type, EX.Empleado))
g.add((empleado2, RDF.type, EX.Empleado))
g.add((empleado3, RDF.type, EX.Empleado))
g.add((empleado4, RDF.type, EX.Empleado))

# Independientes
independiente1 = URIRef(EX.Andres) #
independiente2 = URIRef(EX.Sofia) #
independiente3 = URIRef(EX.Juan) #
independiente4 = URIRef(EX.Valentina) #

g.add((independiente1, RDF.type, EX.Independiente))
g.add((independiente2, RDF.type, EX.Independiente))
g.add((independiente3, RDF.type, EX.Independiente))
g.add((independiente4, RDF.type, EX.Independiente))

# 2️⃣ Ingreso y subclases

ingreso1 = URIRef(EX.Ingreso573)
ingreso2 = URIRef(EX.Ingreso12574893)
ingreso3 = URIRef(EX.Ingreso2389054)
ingreso4 = URIRef(EX.Ingreso567)

g.add((ingreso1, RDF.type, EX.Ingreso))
g.add((ingreso2, RDF.type, EX.Ingreso))
g.add((ingreso3, RDF.type, EX.Ingreso))
g.add((ingreso4, RDF.type, EX.Ingreso))

# Ingreso Fijo
ingreso_fijo1 = URIRef(EX.SalarioMaria) #
ingreso_fijo2 = URIRef(EX.SalarioAlejandro) #
ingreso_fijo3 = URIRef(EX.PensionRosa) #
ingreso_fijo4 = URIRef(EX.PensionManuel) #

g.add((ingreso_fijo1, RDF.type, EX.IngresoFijo))
g.add((ingreso_fijo2, RDF.type, EX.IngresoFijo))
g.add((ingreso_fijo3, RDF.type, EX.IngresoFijo))
g.add((ingreso_fijo4, RDF.type, EX.IngresoFijo))

# Ingreso Variable
ingreso_variable1 = URIRef(EX.VentasAndres) #
ingreso_variable2 = URIRef(EX.ServiciosSofia) #
ingreso_variable3 = URIRef(EX.HonorariosJuan) #
ingreso_variable4 = URIRef(EX.ProyectosValentina) #

g.add((ingreso_variable1, RDF.type, EX.IngresoVariable))
g.add((ingreso_variable2, RDF.type, EX.IngresoVariable))
g.add((ingreso_variable3, RDF.type, EX.IngresoVariable))
g.add((ingreso_variable4, RDF.type, EX.IngresoVariable))

# 3️⃣ Crédito y subclases

credito1 = URIRef(EX.Credito124)
credito2 = URIRef(EX.Credito2346)
credito3 = URIRef(EX.Credito3856)
credito4 = URIRef(EX.Credito478)

g.add((credito1, RDF.type, EX.Credito))
g.add((credito2, RDF.type, EX.Credito))
g.add((credito3, RDF.type, EX.Credito))
g.add((credito4, RDF.type, EX.Credito))

# Libre Inversión
credito_li1 = URIRef(EX.CreditoBodaJose) #
credito_li2 = URIRef(EX.CreditoMueblesCamila) #
credito_li3 = URIRef(EX.CreditoEmergenciaFreddy) #
credito_li4 = URIRef(EX.CreditoEstudiosJeremias) #

g.add((credito_li1, RDF.type, EX.LibreInversion))
g.add((credito_li2, RDF.type, EX.LibreInversion))
g.add((credito_li3, RDF.type, EX.LibreInversion))
g.add((credito_li4, RDF.type, EX.LibreInversion))

# Hipotecario
credito_h1 = URIRef(EX.CreditoCasaMaria) #
credito_h2 = URIRef(EX.CreditoCasaAlejandro) #
credito_h3 = URIRef(EX.CreditoCasaDiana) #
credito_h4 = URIRef(EX.CreditoCasaPedro) #

g.add((credito_h1, RDF.type, EX.CreditoHipotecario))
g.add((credito_h2, RDF.type, EX.CreditoHipotecario))
g.add((credito_h3, RDF.type, EX.CreditoHipotecario))
g.add((credito_h4, RDF.type, EX.CreditoHipotecario))

# Vehicular
credito_v1 = URIRef(EX.CreditoAutoRosa) #
credito_v2 = URIRef(EX.CreditoAutoManuel) #
credito_v3 = URIRef(EX.CreditoMotoLucia) #
credito_v4 = URIRef(EX.CreditoMotoCarlos) #

g.add((credito_v1, RDF.type, EX.CreditoVehicular))
g.add((credito_v2, RDF.type, EX.CreditoVehicular))
g.add((credito_v3, RDF.type, EX.CreditoVehicular))
g.add((credito_v4, RDF.type, EX.CreditoVehicular))

# 4️⃣ Historial y subclases

# PuntajeCrediticio
puntaje1 = URIRef(EX.PuntajeFreddy) #
puntaje2 = URIRef(EX.PuntajeCamila) #
puntaje3 = URIRef(EX.PuntajeJose) #
puntaje4 = URIRef(EX.PuntajeJeremias) #

g.add((puntaje1, RDF.type, EX.PuntajeCrediticio))
g.add((puntaje2, RDF.type, EX.PuntajeCrediticio))
g.add((puntaje3, RDF.type, EX.PuntajeCrediticio))
g.add((puntaje4, RDF.type, EX.PuntajeCrediticio))

# CapacidadEndeudamiento
capacidad1 = URIRef(EX.CapacidadFreddy) #
capacidad2 = URIRef(EX.CapacidadCamila) #
capacidad3 = URIRef(EX.CapacidadJose) #
capacidad4 = URIRef(EX.CapacidadJeremias) #

g.add((capacidad1, RDF.type, EX.CapacidadEndeudamiento))
g.add((capacidad2, RDF.type, EX.CapacidadEndeudamiento))
g.add((capacidad3, RDF.type, EX.CapacidadEndeudamiento))
g.add((capacidad4, RDF.type, EX.CapacidadEndeudamiento))

# ------------ SERIALIZAR PARA VER RESULTADO ------------
print(g.serialize(format="turtle"))
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix ex: <http://practica1.org/evaluacion_creditos#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:CapacidadEndeudamiento a rdfs:Class ;
#     rdfs:subClassOf ex:Historial .
#
# ex:Credito a rdfs:Class .
#
# ex:CreditoHipotecario a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:CreditoVehicular a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:Empleado a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Estudiante a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Historial a rdfs:Class .
#
# ex:Independiente a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Ingreso a rdfs:Class .
#
# ex:IngresoFijo a rdfs:Class ;
#     rdfs:subClassOf ex:Ingreso .
#
# ex:IngresoVariable a rdfs:Class ;
#     rdfs:subClassOf ex:Ingreso .
#
# ex:Jubilado a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:LibreInversion a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:Persona a rdfs:Class .
#
# ex:PuntajeCrediticio a rdfs:Class ;
#     rdfs:subClassOf ex:Historial .
#
# ex:Alejandro a ex:Empleado .
#
# ex:Andres a ex:Independiente .
#
# ex:Camila a ex:Estudiante .
#
# ex:CapacidadCamila a ex:CapacidadEndeudamiento .
#
# ex:CapacidadFreddy a ex:CapacidadEndeudamiento .
#
# ex:CapacidadJeremias a ex:CapacidadEndeudamiento .
#
# ex:CapacidadJose a ex:CapacidadEndeudamiento .
#
# ex:Carlos a ex:Jubilado .
#
# ex:Credito124 a ex:Credito .
#
# ex:Credito2346 a ex:Credito .
#
# ex:Credito3856 a ex:Credito .
#
# ex:Credito478 a ex:Credito .
#
# ex:CreditoAutoManuel a ex:CreditoVehicular .
#
# ex:CreditoAutoRosa a ex:CreditoVehicular .
#
# ex:CreditoBodaJose a ex:LibreInversion .
#
# ex:CreditoCasaAlejandro a ex:CreditoHipotecario .
#
# ex:CreditoCasaDiana a ex:CreditoHipotecario .
#
# ex:CreditoCasaMaria a ex:CreditoHipotecario .
#
# ex:CreditoCasaPedro a ex:CreditoHipotecario .
#
# ex:CreditoEmergenciaFreddy a ex:LibreInversion .
#
# ex:CreditoEstudiosJeremias a ex:LibreInversion .
#
# ex:CreditoMotoCarlos a ex:CreditoVehicular .
#
# ex:CreditoMotoLucia a ex:CreditoVehicular .
#
# ex:CreditoMueblesCamila a ex:LibreInversion .
#
# ex:Diana a ex:Empleado .
#
# ex:Freddy a ex:Estudiante .
#
# ex:HonorariosJuan a ex:IngresoVariable .
#
# ex:Ingreso12574893 a ex:Ingreso .
#
# ex:Ingreso2389054 a ex:Ingreso .
#
# ex:Ingreso567 a ex:Ingreso .
#
# ex:Ingreso573 a ex:Ingreso .
#
# ex:Jeremias a ex:Estudiante .
#
# ex:Jose a ex:Estudiante .
#
# ex:Juan a ex:Independiente .
#
# ex:Lucia a ex:Jubilado .
#
# ex:Manuel a ex:Jubilado .
#
# ex:Maria a ex:Empleado .
#
# ex:Pedro a ex:Empleado .
#
# ex:PensionManuel a ex:IngresoFijo .
#
# ex:PensionRosa a ex:IngresoFijo .
#
# ex:Persona221 a ex:Persona .
#
# ex:Persona3654 a ex:Persona .
#
# ex:Persona6798 a ex:Persona .
#
# ex:Persona786 a ex:Persona .
#
# ex:ProyectosValentina a ex:IngresoVariable .
#
# ex:PuntajeCamila a ex:PuntajeCrediticio .
#
# ex:PuntajeFreddy a ex:PuntajeCrediticio .
#
# ex:PuntajeJeremias a ex:PuntajeCrediticio .
#
# ex:PuntajeJose a ex:PuntajeCrediticio .
#
# ex:Rosa a ex:Jubilado .
#
# ex:SalarioAlejandro a ex:IngresoFijo .
#
# ex:SalarioMaria a ex:IngresoFijo .
#
# ex:ServiciosSofia a ex:IngresoVariable .
#
# ex:Sofia a ex:Independiente .
#
# ex:Valentina a ex:Independiente .
#
# ex:VentasAndres a ex:IngresoVariable .
#
# ex:anioNacimiento a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:gYear .
#
# ex:capacidadEndeudamiento a rdf:Property ;
#     rdfs:domain ex:Historial ;
#     rdfs:range xsd:decimal .
#
# ex:coSolicitante a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf foaf:knows .
#
# ex:estabilidadLaboral a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:string .
#
# ex:estadoCredito a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:string .
#
# ex:montoAprobado a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto .
#
# ex:montoIngreso a rdf:Property ;
#     rdfs:domain ex:Ingreso ;
#     rdfs:range xsd:decimal .
#
# ex:montoSolicitado a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto .
#
# ex:plazo a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:integer .
#
# ex:puntajeCrediticio a rdf:Property ;
#     rdfs:domain ex:Historial ;
#     rdfs:range xsd:decimal .
#
# ex:referido a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf foaf:knows .
#
# ex:tieneCredito a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Credito .
#
# ex:tieneHistorial a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Historial .
#
# ex:tieneIngreso a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Ingreso .
#
# dc:identifier a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:string .
#
# foaf:name a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:string .
#
# ex:monto a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal .
#
# foaf:knows a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona .

# %% [markdown]
# ### Razonamiento

# %% [markdown]
# #### Generación de Hechos Iniciales

# %%
# ------------ Hechos ------------
g.add((estudiante1, EX.tieneCredito, credito_li3))
g.add((estudiante1, EX.tieneHistorial, puntaje1))
g.add((estudiante1, EX.tieneHistorial, capacidad1))

g.add((estudiante2, EX.tieneCredito, credito_li1))
g.add((estudiante2, EX.tieneHistorial, puntaje3))
g.add((estudiante2, EX.tieneHistorial, capacidad3))

g.add((estudiante3, EX.tieneCredito, credito_li2))
g.add((estudiante3, EX.tieneHistorial, puntaje2))
g.add((estudiante3, EX.tieneHistorial, capacidad2))

g.add((estudiante4, EX.tieneCredito, credito_li4))
g.add((estudiante4, EX.tieneHistorial, puntaje4))
g.add((estudiante4, EX.tieneHistorial, capacidad4))


g.add((jubilado1, EX.tieneIngreso, ingreso_fijo3))
g.add((jubilado1, EX.tieneCredito, credito_v1))

g.add((jubilado2, EX.tieneIngreso, ingreso_fijo4))
g.add((jubilado2, EX.tieneCredito, credito_v2))

g.add((jubilado3, EX.tieneCredito, credito_v3))

g.add((jubilado4, EX.tieneCredito, credito_v4))


g.add((empleado1, EX.tieneIngreso, ingreso_fijo1))
g.add((empleado1, EX.tieneCredito, credito_h1))

g.add((empleado2, EX.tieneIngreso, ingreso_fijo2))
g.add((empleado2, EX.tieneCredito, credito_h2))

g.add((empleado3, EX.tieneCredito, credito_h3))

g.add((empleado4, EX.tieneCredito, credito_h4))


g.add((independiente1, EX.tieneIngreso, ingreso_variable1))

g.add((independiente2, EX.tieneIngreso, ingreso_variable2))

g.add((independiente3, EX.tieneIngreso, ingreso_variable3))

g.add((independiente4, EX.tieneIngreso, ingreso_variable4))

# ------------ SERIALIZAR PARA VER RESULTADO ------------
print(g.serialize(format="turtle"))
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix ex: <http://practica1.org/evaluacion_creditos#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:CapacidadEndeudamiento a rdfs:Class ;
#     rdfs:subClassOf ex:Historial .
#
# ex:Credito a rdfs:Class .
#
# ex:CreditoHipotecario a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:CreditoVehicular a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:Empleado a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Estudiante a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Historial a rdfs:Class .
#
# ex:Independiente a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:Ingreso a rdfs:Class .
#
# ex:IngresoFijo a rdfs:Class ;
#     rdfs:subClassOf ex:Ingreso .
#
# ex:IngresoVariable a rdfs:Class ;
#     rdfs:subClassOf ex:Ingreso .
#
# ex:Jubilado a rdfs:Class ;
#     rdfs:subClassOf ex:Persona .
#
# ex:LibreInversion a rdfs:Class ;
#     rdfs:subClassOf ex:Credito .
#
# ex:Persona a rdfs:Class .
#
# ex:PuntajeCrediticio a rdfs:Class ;
#     rdfs:subClassOf ex:Historial .
#
# ex:Alejandro a ex:Empleado ;
#     ex:tieneCredito ex:CreditoCasaAlejandro ;
#     ex:tieneIngreso ex:SalarioAlejandro .
#
# ex:Andres a ex:Independiente ;
#     ex:tieneIngreso ex:VentasAndres .
#
# ex:Camila a ex:Estudiante ;
#     ex:tieneCredito ex:CreditoMueblesCamila ;
#     ex:tieneHistorial ex:CapacidadCamila,
#         ex:PuntajeCamila .
#
# ex:Carlos a ex:Jubilado ;
#     ex:tieneCredito ex:CreditoMotoCarlos .
#
# ex:Credito124 a ex:Credito .
#
# ex:Credito2346 a ex:Credito .
#
# ex:Credito3856 a ex:Credito .
#
# ex:Credito478 a ex:Credito .
#
# ex:Diana a ex:Empleado ;
#     ex:tieneCredito ex:CreditoCasaDiana .
#
# ex:Freddy a ex:Estudiante ;
#     ex:tieneCredito ex:CreditoEmergenciaFreddy ;
#     ex:tieneHistorial ex:CapacidadFreddy,
#         ex:PuntajeFreddy .
#
# ex:Ingreso12574893 a ex:Ingreso .
#
# ex:Ingreso2389054 a ex:Ingreso .
#
# ex:Ingreso567 a ex:Ingreso .
#
# ex:Ingreso573 a ex:Ingreso .
#
# ex:Jeremias a ex:Estudiante ;
#     ex:tieneCredito ex:CreditoEstudiosJeremias ;
#     ex:tieneHistorial ex:CapacidadJeremias,
#         ex:PuntajeJeremias .
#
# ex:Jose a ex:Estudiante ;
#     ex:tieneCredito ex:CreditoBodaJose ;
#     ex:tieneHistorial ex:CapacidadJose,
#         ex:PuntajeJose .
#
# ex:Juan a ex:Independiente ;
#     ex:tieneIngreso ex:HonorariosJuan .
#
# ex:Lucia a ex:Jubilado ;
#     ex:tieneCredito ex:CreditoMotoLucia .
#
# ex:Manuel a ex:Jubilado ;
#     ex:tieneCredito ex:CreditoAutoManuel ;
#     ex:tieneIngreso ex:PensionManuel .
#
# ex:Maria a ex:Empleado ;
#     ex:tieneCredito ex:CreditoCasaMaria ;
#     ex:tieneIngreso ex:SalarioMaria .
#
# ex:Pedro a ex:Empleado ;
#     ex:tieneCredito ex:CreditoCasaPedro .
#
# ex:Persona221 a ex:Persona .
#
# ex:Persona3654 a ex:Persona .
#
# ex:Persona6798 a ex:Persona .
#
# ex:Persona786 a ex:Persona .
#
# ex:Rosa a ex:Jubilado ;
#     ex:tieneCredito ex:CreditoAutoRosa ;
#     ex:tieneIngreso ex:PensionRosa .
#
# ex:Sofia a ex:Independiente ;
#     ex:tieneIngreso ex:ServiciosSofia .
#
# ex:Valentina a ex:Independiente ;
#     ex:tieneIngreso ex:ProyectosValentina .
#
# ex:anioNacimiento a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:gYear .
#
# ex:capacidadEndeudamiento a rdf:Property ;
#     rdfs:domain ex:Historial ;
#     rdfs:range xsd:decimal .
#
# ex:coSolicitante a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf foaf:knows .
#
# ex:estabilidadLaboral a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:string .
#
# ex:estadoCredito a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:string .
#
# ex:montoAprobado a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto .
#
# ex:montoIngreso a rdf:Property ;
#     rdfs:domain ex:Ingreso ;
#     rdfs:range xsd:decimal .
#
# ex:montoSolicitado a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto .
#
# ex:plazo a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:integer .
#
# ex:puntajeCrediticio a rdf:Property ;
#     rdfs:domain ex:Historial ;
#     rdfs:range xsd:decimal .
#
# ex:referido a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf foaf:knows .
#
# ex:tieneCredito a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Credito .
#
# ex:tieneHistorial a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Historial .
#
# ex:tieneIngreso a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Ingreso .
#
# dc:identifier a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:string .
#
# foaf:name a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:string .
#
# ex:CapacidadCamila a ex:CapacidadEndeudamiento .
#
# ex:CapacidadFreddy a ex:CapacidadEndeudamiento .
#
# ex:CapacidadJeremias a ex:CapacidadEndeudamiento .
#
# ex:CapacidadJose a ex:CapacidadEndeudamiento .
#
# ex:CreditoAutoManuel a ex:CreditoVehicular .
#
# ex:CreditoAutoRosa a ex:CreditoVehicular .
#
# ex:CreditoBodaJose a ex:LibreInversion .
#
# ex:CreditoCasaAlejandro a ex:CreditoHipotecario .
#
# ex:CreditoCasaDiana a ex:CreditoHipotecario .
#
# ex:CreditoCasaMaria a ex:CreditoHipotecario .
#
# ex:CreditoCasaPedro a ex:CreditoHipotecario .
#
# ex:CreditoEmergenciaFreddy a ex:LibreInversion .
#
# ex:CreditoEstudiosJeremias a ex:LibreInversion .
#
# ex:CreditoMotoCarlos a ex:CreditoVehicular .
#
# ex:CreditoMotoLucia a ex:CreditoVehicular .
#
# ex:CreditoMueblesCamila a ex:LibreInversion .
#
# ex:HonorariosJuan a ex:IngresoVariable .
#
# ex:PensionManuel a ex:IngresoFijo .
#
# ex:PensionRosa a ex:IngresoFijo .
#
# ex:ProyectosValentina a ex:IngresoVariable .
#
# ex:PuntajeCamila a ex:PuntajeCrediticio .
#
# ex:PuntajeFreddy a ex:PuntajeCrediticio .
#
# ex:PuntajeJeremias a ex:PuntajeCrediticio .
#
# ex:PuntajeJose a ex:PuntajeCrediticio .
#
# ex:SalarioAlejandro a ex:IngresoFijo .
#
# ex:SalarioMaria a ex:IngresoFijo .
#
# ex:ServiciosSofia a ex:IngresoVariable .
#
# ex:VentasAndres a ex:IngresoVariable .
#
# ex:monto a rdf:Property ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal .
#
# foaf:knows a rdf:Property ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona .

# %% [markdown]
# #### Deducciones

# %%
from owlrl import DeductiveClosure, RDFS_Semantics

def consulta(caso):
    if caso == 1:
        for s, p, o in g.triples((EX.Freddy, RDF.type, None)):
            print(s, p, o)
        print("---")
        for s, p, o in g.triples((EX.ProyectosValentina, RDF.type, None)):
            print(s, p, o)

    elif caso == 2:
        for s, p, o in g.triples((EX.Marta, None, None)):
            print(s, p, o)
        for s, p, o in g.triples((EX.CreditoViajeMarta, None, None)):
            print(s, p, o)
            
    elif caso == 3:
        for s, p, o in g.triples((EX.Juan, None, EX.Rosa)):
            print(s, p, o)
    
    elif caso == 4:
        for s, p, o in g.triples((EX.CreditoAutoRosa, None, None)):
            if str(o) == "500000":
                print(s, p, o)

    elif caso == 5:
        for s, p, o in g.triples((EX.CreditoCasaAlejandro, RDF.type, None)):
            print(s, p, o)  

    elif caso == 6:
        for s, p, o in g.triples((EX.CapacidadJose, RDF.type, None)):
            print(s, p, o)

    elif caso == 7:
        for s, p, o in g.triples((EX.ingresoDesconocidoFreddy, RDF.type, None)):
            print(s, p, o)
        for s, p, o in g.triples((EX.Freddy, EX.tieneIngreso, None)):
            print(s, p, o)


# ------------ ANTES ------------
print("Antes de la inferencia:")

# Caso 1
print("\nCaso 1: Freddy es estudiante y ProyectosValentina es un ingreso variable")
consulta(1)

# Caso 2
credito_li5 = URIRef(EX.CreditoViajeMarta)
independiente5 = URIRef(EX.Marta)
g.add((independiente5, EX.tieneCredito, credito_li5))

print("\nCaso 2: Marta tiene un crédito CreditoViajeMarta pero no se saben sus tipos")
consulta(2)

# Caso 3
g.add((EX.Juan, EX.referido, EX.Rosa))

print("\nCaso 3: Juan tiene como referido a Rosa")
consulta(3)

# 4 Casos adicionales
print("\nCaso adicional 1: CreditoAutoRosa tiene un monto solicitado de 500000")
g.add((credito_v1, EX.montoSolicitado, Literal(500000, datatype=XSD.decimal)))
consulta(4)

print("\nCaso adicional 2: CreditoCasaAlejandro es un CreditoHipotecario solamente")
consulta(5)

print("\nCaso adicional 3: CapacidadJose es una CapacidadEndeudamiento solamente")
consulta(6)

print("\nCaso adicional 4: Freddy tiene un ingreso desconocido del que no se especifica su tipo")
ingreso_desconocido = URIRef(EX.ingresoDesconocidoFreddy)
g.add((estudiante1, EX.tieneIngreso, ingreso_desconocido))
consulta(7)

print("\n****************************************************************************")
#------------ DESPUÉS ------------
DeductiveClosure(RDFS_Semantics, axiomatic_triples=True, datatype_axioms=False).expand(g)
print("\nDespués de la inferencia:")

print("\nCaso 1: Ahora se sabe que Freddy es Persona y ProyectosValentina es un Ingreso")
consulta(1)

print("\nCaso 2: Ahora se sabe que Marta es Persona y CreditoViajeMarta es un Credito")
consulta(2)

print("\nCaso 3: Ahora se sabe que Juan knows (conoce) a Rosa")
consulta(3)

# 4 Casos adicionales
print("\nCaso adicional 1: CreditoAutoRosa tiene un monto de 500000m, por jerarquía de propiedades (Caso 3)") 
consulta(4)
print("\nCaso adicional 2: CreditoCasaAlejandro es ahora también de tipo Credito (Caso 1)")
consulta(5)
print("\nCaso adicional 3: CapacidadJose es ahora también de tipo Historial (Caso 1)")
consulta(6)
print("\nCaso adicional 4: Ingreso desconocido de Freddy ahora es de tipo Ingreso (Caso 2)")
consulta(7)
# Out:
# Antes de la inferencia:
#
# Caso 1: Freddy es estudiante y ProyectosValentina es un ingreso variable
# http://practica1.org/evaluacion_creditos#Freddy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Estudiante
# ---
# http://practica1.org/evaluacion_creditos#ProyectosValentina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#IngresoVariable
#
# Caso 2: Marta tiene un crédito CreditoViajeMarta pero no se saben sus tipos
# http://practica1.org/evaluacion_creditos#Marta http://practica1.org/evaluacion_creditos#tieneCredito http://practica1.org/evaluacion_creditos#CreditoViajeMarta
#
# Caso 3: Juan tiene como referido a Rosa
# http://practica1.org/evaluacion_creditos#Juan http://practica1.org/evaluacion_creditos#referido http://practica1.org/evaluacion_creditos#Rosa
#
# Caso adicional 1: CreditoAutoRosa tiene un monto solicitado de 500000
# http://practica1.org/evaluacion_creditos#CreditoAutoRosa http://practica1.org/evaluacion_creditos#montoSolicitado 500000
#
# Caso adicional 2: CreditoCasaAlejandro es un CreditoHipotecario solamente
# http://practica1.org/evaluacion_creditos#CreditoCasaAlejandro http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#CreditoHipotecario
#
# Caso adicional 3: CapacidadJose es una CapacidadEndeudamiento solamente
# http://practica1.org/evaluacion_creditos#CapacidadJose http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#CapacidadEndeudamiento
#
# Caso adicional 4: Freddy tiene un ingreso desconocido del que no se especifica su tipo
# http://practica1.org/evaluacion_creditos#Freddy http://practica1.org/evaluacion_creditos#tieneIngreso http://practica1.org/evaluacion_creditos#ingresoDesconocidoFreddy
#
# ****************************************************************************
#
# Después de la inferencia:
#
# Caso 1: Ahora se sabe que Freddy es Persona y ProyectosValentina es un Ingreso
# http://practica1.org/evaluacion_creditos#Freddy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Estudiante
# http://practica1.org/evaluacion_creditos#Freddy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://practica1.org/evaluacion_creditos#Freddy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Persona
# ---
# http://practica1.org/evaluacion_creditos#ProyectosValentina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#IngresoVariable
# http://practica1.org/evaluacion_creditos#ProyectosValentina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Ingreso
# http://practica1.org/evaluacion_creditos#ProyectosValentina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
#
# Caso 2: Ahora se sabe que Marta es Persona y CreditoViajeMarta es un Credito
# http://practica1.org/evaluacion_creditos#Marta http://practica1.org/evaluacion_creditos#tieneCredito http://practica1.org/evaluacion_creditos#CreditoViajeMarta
# http://practica1.org/evaluacion_creditos#Marta http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Persona
# http://practica1.org/evaluacion_creditos#Marta http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://practica1.org/evaluacion_creditos#CreditoViajeMarta http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Credito
# http://practica1.org/evaluacion_creditos#CreditoViajeMarta http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
#
# Caso 3: Ahora se sabe que Juan knows (conoce) a Rosa
# http://practica1.org/evaluacion_creditos#Juan http://practica1.org/evaluacion_creditos#referido http://practica1.org/evaluacion_creditos#Rosa
# http://practica1.org/evaluacion_creditos#Juan http://xmlns.com/foaf/0.1/knows http://practica1.org/evaluacion_creditos#Rosa
#
# Caso adicional 1: CreditoAutoRosa tiene un monto de 500000m, por jerarquía de propiedades (Caso 3)
# http://practica1.org/evaluacion_creditos#CreditoAutoRosa http://practica1.org/evaluacion_creditos#montoSolicitado 500000
# http://practica1.org/evaluacion_creditos#CreditoAutoRosa http://practica1.org/evaluacion_creditos#monto 500000
#
# Caso adicional 2: CreditoCasaAlejandro es ahora también de tipo Credito (Caso 1)
# http://practica1.org/evaluacion_creditos#CreditoCasaAlejandro http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#CreditoHipotecario
# http://practica1.org/evaluacion_creditos#CreditoCasaAlejandro http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://practica1.org/evaluacion_creditos#CreditoCasaAlejandro http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Credito
#
# Caso adicional 3: CapacidadJose es ahora también de tipo Historial (Caso 1)
# http://practica1.org/evaluacion_creditos#CapacidadJose http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#CapacidadEndeudamiento
# http://practica1.org/evaluacion_creditos#CapacidadJose http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://practica1.org/evaluacion_creditos#CapacidadJose http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Historial
#
# Caso adicional 4: Ingreso desconocido de Freddy ahora es de tipo Ingreso (Caso 2)
# http://practica1.org/evaluacion_creditos#ingresoDesconocidoFreddy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://practica1.org/evaluacion_creditos#ingresoDesconocidoFreddy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://practica1.org/evaluacion_creditos#Ingreso
# http://practica1.org/evaluacion_creditos#Freddy http://practica1.org/evaluacion_creditos#tieneIngreso http://practica1.org/evaluacion_creditos#ingresoDesconocidoFreddy

# %%
# ------------ SERIALIZAR PARA COMPARAR RESULTADO ------------
print(g.serialize(format="turtle"))
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix ex: <http://practica1.org/evaluacion_creditos#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:CapacidadEndeudamiento a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:CapacidadEndeudamiento,
#         ex:Historial,
#         rdfs:Resource .
#
# ex:Credito a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Credito,
#         rdfs:Resource .
#
# ex:CreditoHipotecario a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Credito,
#         ex:CreditoHipotecario,
#         rdfs:Resource .
#
# ex:CreditoVehicular a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Credito,
#         ex:CreditoVehicular,
#         rdfs:Resource .
#
# ex:Empleado a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Empleado,
#         ex:Persona,
#         rdfs:Resource .
#
# ex:Estudiante a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Estudiante,
#         ex:Persona,
#         rdfs:Resource .
#
# ex:Historial a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Historial,
#         rdfs:Resource .
#
# ex:Independiente a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Independiente,
#         ex:Persona,
#         rdfs:Resource .
#
# ex:Ingreso a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Ingreso,
#         rdfs:Resource .
#
# ex:IngresoFijo a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Ingreso,
#         ex:IngresoFijo,
#         rdfs:Resource .
#
# ex:IngresoVariable a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Ingreso,
#         ex:IngresoVariable,
#         rdfs:Resource .
#
# ex:Jubilado a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Jubilado,
#         ex:Persona,
#         rdfs:Resource .
#
# ex:LibreInversion a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Credito,
#         ex:LibreInversion,
#         rdfs:Resource .
#
# ex:Persona a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Persona,
#         rdfs:Resource .
#
# ex:PuntajeCrediticio a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf ex:Historial,
#         ex:PuntajeCrediticio,
#         rdfs:Resource .
#
# rdf:Alt a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:Alt,
#         rdfs:Container,
#         rdfs:Resource .
#
# rdf:Bag a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:Bag,
#         rdfs:Container,
#         rdfs:Resource .
#
# rdf:List a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:List,
#         rdfs:Resource .
#
# rdf:Property a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:Property,
#         rdfs:Resource .
#
# rdf:Seq a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:Seq,
#         rdfs:Container,
#         rdfs:Resource .
#
# rdf:Statement a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:Statement,
#         rdfs:Resource .
#
# rdf:XMLLiteral a rdfs:Class,
#         rdfs:Datatype,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:XMLLiteral,
#         rdfs:Literal,
#         rdfs:Resource .
#
# rdfs:Class a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Class,
#         rdfs:Resource .
#
# rdfs:Container a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Container,
#         rdfs:Resource .
#
# rdfs:ContainerMembershipProperty a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdf:Property,
#         rdfs:ContainerMembershipProperty,
#         rdfs:Resource .
#
# rdfs:Datatype a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Class,
#         rdfs:Datatype,
#         rdfs:Resource .
#
# rdfs:Literal a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Literal,
#         rdfs:Resource .
#
# rdfs:Resource a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Resource .
#
# xsd:decimal a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Resource,
#         xsd:decimal .
#
# xsd:gYear a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Resource,
#         xsd:gYear .
#
# xsd:integer a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Resource,
#         xsd:integer .
#
# xsd:string a rdfs:Class,
#         rdfs:Resource ;
#     rdfs:subClassOf rdfs:Resource,
#         xsd:string .
#
# ex:Alejandro a ex:Empleado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoCasaAlejandro ;
#     ex:tieneIngreso ex:SalarioAlejandro .
#
# ex:Andres a ex:Independiente,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneIngreso ex:VentasAndres .
#
# ex:Camila a ex:Estudiante,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoMueblesCamila ;
#     ex:tieneHistorial ex:CapacidadCamila,
#         ex:PuntajeCamila .
#
# ex:Carlos a ex:Jubilado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoMotoCarlos .
#
# ex:Credito124 a ex:Credito,
#         rdfs:Resource .
#
# ex:Credito2346 a ex:Credito,
#         rdfs:Resource .
#
# ex:Credito3856 a ex:Credito,
#         rdfs:Resource .
#
# ex:Credito478 a ex:Credito,
#         rdfs:Resource .
#
# ex:Diana a ex:Empleado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoCasaDiana .
#
# ex:Freddy a ex:Estudiante,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoEmergenciaFreddy ;
#     ex:tieneHistorial ex:CapacidadFreddy,
#         ex:PuntajeFreddy ;
#     ex:tieneIngreso ex:ingresoDesconocidoFreddy .
#
# ex:Ingreso12574893 a ex:Ingreso,
#         rdfs:Resource .
#
# ex:Ingreso2389054 a ex:Ingreso,
#         rdfs:Resource .
#
# ex:Ingreso567 a ex:Ingreso,
#         rdfs:Resource .
#
# ex:Ingreso573 a ex:Ingreso,
#         rdfs:Resource .
#
# ex:Jeremias a ex:Estudiante,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoEstudiosJeremias ;
#     ex:tieneHistorial ex:CapacidadJeremias,
#         ex:PuntajeJeremias .
#
# ex:Jose a ex:Estudiante,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoBodaJose ;
#     ex:tieneHistorial ex:CapacidadJose,
#         ex:PuntajeJose .
#
# ex:Juan a ex:Independiente,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:referido ex:Rosa ;
#     ex:tieneIngreso ex:HonorariosJuan ;
#     foaf:knows ex:Rosa .
#
# ex:Lucia a ex:Jubilado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoMotoLucia .
#
# ex:Manuel a ex:Jubilado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoAutoManuel ;
#     ex:tieneIngreso ex:PensionManuel .
#
# ex:Maria a ex:Empleado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoCasaMaria ;
#     ex:tieneIngreso ex:SalarioMaria .
#
# ex:Marta a ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoViajeMarta .
#
# ex:Pedro a ex:Empleado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoCasaPedro .
#
# ex:Persona221 a ex:Persona,
#         rdfs:Resource .
#
# ex:Persona3654 a ex:Persona,
#         rdfs:Resource .
#
# ex:Persona6798 a ex:Persona,
#         rdfs:Resource .
#
# ex:Persona786 a ex:Persona,
#         rdfs:Resource .
#
# ex:Sofia a ex:Independiente,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneIngreso ex:ServiciosSofia .
#
# ex:Valentina a ex:Independiente,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneIngreso ex:ProyectosValentina .
#
# () a rdf:List,
#         rdfs:Resource .
#
# ex:CapacidadCamila a ex:CapacidadEndeudamiento,
#         ex:Historial,
#         rdfs:Resource .
#
# ex:CapacidadFreddy a ex:CapacidadEndeudamiento,
#         ex:Historial,
#         rdfs:Resource .
#
# ex:CapacidadJeremias a ex:CapacidadEndeudamiento,
#         ex:Historial,
#         rdfs:Resource .
#
# ex:CapacidadJose a ex:CapacidadEndeudamiento,
#         ex:Historial,
#         rdfs:Resource .
#
# ex:CreditoAutoManuel a ex:Credito,
#         ex:CreditoVehicular,
#         rdfs:Resource .
#
# ex:CreditoAutoRosa a ex:Credito,
#         ex:CreditoVehicular,
#         rdfs:Resource ;
#     ex:monto 500000.0 ;
#     ex:montoSolicitado 500000.0 .
#
# ex:CreditoBodaJose a ex:Credito,
#         ex:LibreInversion,
#         rdfs:Resource .
#
# ex:CreditoCasaAlejandro a ex:Credito,
#         ex:CreditoHipotecario,
#         rdfs:Resource .
#
# ex:CreditoCasaDiana a ex:Credito,
#         ex:CreditoHipotecario,
#         rdfs:Resource .
#
# ex:CreditoCasaMaria a ex:Credito,
#         ex:CreditoHipotecario,
#         rdfs:Resource .
#
# ex:CreditoCasaPedro a ex:Credito,
#         ex:CreditoHipotecario,
#         rdfs:Resource .
#
# ex:CreditoEmergenciaFreddy a ex:Credito,
#         ex:LibreInversion,
#         rdfs:Resource .
#
# ex:CreditoEstudiosJeremias a ex:Credito,
#         ex:LibreInversion,
#         rdfs:Resource .
#
# ex:CreditoMotoCarlos a ex:Credito,
#         ex:CreditoVehicular,
#         rdfs:Resource .
#
# ex:CreditoMotoLucia a ex:Credito,
#         ex:CreditoVehicular,
#         rdfs:Resource .
#
# ex:CreditoMueblesCamila a ex:Credito,
#         ex:LibreInversion,
#         rdfs:Resource .
#
# ex:CreditoViajeMarta a ex:Credito,
#         rdfs:Resource .
#
# ex:HonorariosJuan a ex:Ingreso,
#         ex:IngresoVariable,
#         rdfs:Resource .
#
# ex:PensionManuel a ex:Ingreso,
#         ex:IngresoFijo,
#         rdfs:Resource .
#
# ex:PensionRosa a ex:Ingreso,
#         ex:IngresoFijo,
#         rdfs:Resource .
#
# ex:ProyectosValentina a ex:Ingreso,
#         ex:IngresoVariable,
#         rdfs:Resource .
#
# ex:PuntajeCamila a ex:Historial,
#         ex:PuntajeCrediticio,
#         rdfs:Resource .
#
# ex:PuntajeFreddy a ex:Historial,
#         ex:PuntajeCrediticio,
#         rdfs:Resource .
#
# ex:PuntajeJeremias a ex:Historial,
#         ex:PuntajeCrediticio,
#         rdfs:Resource .
#
# ex:PuntajeJose a ex:Historial,
#         ex:PuntajeCrediticio,
#         rdfs:Resource .
#
# ex:SalarioAlejandro a ex:Ingreso,
#         ex:IngresoFijo,
#         rdfs:Resource .
#
# ex:SalarioMaria a ex:Ingreso,
#         ex:IngresoFijo,
#         rdfs:Resource .
#
# ex:ServiciosSofia a ex:Ingreso,
#         ex:IngresoVariable,
#         rdfs:Resource .
#
# ex:VentasAndres a ex:Ingreso,
#         ex:IngresoVariable,
#         rdfs:Resource .
#
# ex:anioNacimiento a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:gYear ;
#     rdfs:subPropertyOf ex:anioNacimiento .
#
# ex:capacidadEndeudamiento a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Historial ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:capacidadEndeudamiento .
#
# ex:coSolicitante a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf ex:coSolicitante,
#         foaf:knows .
#
# ex:estabilidadLaboral a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf ex:estabilidadLaboral .
#
# ex:estadoCredito a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf ex:estadoCredito .
#
# ex:ingresoDesconocidoFreddy a ex:Ingreso,
#         rdfs:Resource .
#
# ex:montoAprobado a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto,
#         ex:montoAprobado .
#
# ex:montoIngreso a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Ingreso ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:montoIngreso .
#
# ex:montoSolicitado a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto,
#         ex:montoSolicitado .
#
# ex:plazo a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:integer ;
#     rdfs:subPropertyOf ex:plazo .
#
# ex:puntajeCrediticio a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Historial ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:puntajeCrediticio .
#
# ex:referido a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf ex:referido,
#         foaf:knows .
#
# ex:tieneCredito a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Credito ;
#     rdfs:subPropertyOf ex:tieneCredito .
#
# ex:tieneHistorial a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Historial ;
#     rdfs:subPropertyOf ex:tieneHistorial .
#
# ex:tieneIngreso a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Ingreso ;
#     rdfs:subPropertyOf ex:tieneIngreso .
#
# dc:identifier a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf dc:identifier .
#
# rdf:first a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:List ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdf:first .
#
# rdf:object a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:Statement ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdf:object .
#
# rdf:predicate a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:Statement ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdf:predicate .
#
# rdf:rest a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:List ;
#     rdfs:range rdf:List ;
#     rdfs:subPropertyOf rdf:rest .
#
# rdf:subject a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:Statement ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdf:subject .
#
# rdf:type a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Class ;
#     rdfs:subPropertyOf rdf:type .
#
# rdf:value a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdf:value .
#
# rdfs:comment a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Literal ;
#     rdfs:subPropertyOf rdfs:comment .
#
# rdfs:domain a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:Property ;
#     rdfs:range rdfs:Class ;
#     rdfs:subPropertyOf rdfs:domain .
#
# rdfs:isDefinedBy a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdfs:isDefinedBy,
#         rdfs:seeAlso .
#
# rdfs:label a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Literal ;
#     rdfs:subPropertyOf rdfs:label .
#
# rdfs:member a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdfs:member .
#
# rdfs:range a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:Property ;
#     rdfs:range rdfs:Class ;
#     rdfs:subPropertyOf rdfs:range .
#
# rdfs:subClassOf a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Class ;
#     rdfs:range rdfs:Class ;
#     rdfs:subPropertyOf rdfs:subClassOf .
#
# rdfs:subPropertyOf a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdf:Property ;
#     rdfs:range rdf:Property ;
#     rdfs:subPropertyOf rdfs:subPropertyOf .
#
# foaf:name a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf foaf:name .
#
# ex:Rosa a ex:Jubilado,
#         ex:Persona,
#         rdfs:Resource ;
#     ex:tieneCredito ex:CreditoAutoRosa ;
#     ex:tieneIngreso ex:PensionRosa .
#
# rdfs:seeAlso a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain rdfs:Resource ;
#     rdfs:range rdfs:Resource ;
#     rdfs:subPropertyOf rdfs:seeAlso .
#
# 500000.0 a rdfs:Resource,
#         xsd:decimal .
#
# ex:monto a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Credito ;
#     rdfs:range xsd:decimal ;
#     rdfs:subPropertyOf ex:monto .
#
# foaf:knows a rdf:Property,
#         rdfs:Resource ;
#     rdfs:domain ex:Persona ;
#     rdfs:range ex:Persona ;
#     rdfs:subPropertyOf foaf:knows .

# %% [markdown]
# # Sistema Experta

# %% [markdown]
# # Reglas Sistema Experta
#
# ## Reglas Prioridad Alta - Rechazar Credito
#
# - **Regla 1**: Si la persona es menor de edad (< 18 años), se rechaza el crédito.
# - **Regla 2**: Si la persona es mayor de 75 años, se rechaza el crédito.
# - **Regla 3**: Si el riesgo de impago > 0.8, se rechaza el crédito.
# - **Regla 4**: Si el sueldo es menor a 1 millones de pesos, se rechaza el crédito.
# - **Regla 5**: Si el puntaje crediticio < 300, se rechaza el crédito.
# - **Regla 6**: Si el monto solicitado supera a la capacidad de endeudamiento, se rechaza el crédito.
# - **Regla 7**: Si el plazo del crédito supera los 60 meses, se rechaza el crédito.
#
# ## Reglas Prioridad Media - Aceptar Credito
#
# - **Regla 8**: Si el monto solicitado es menor o igual a 5 millones de pesos, se aprueba sin calcular interés.
# - **Regla 9**: Si el riesgo de impago es ≤ 0.4, se aprueba sin calcular interés.
# - **Regla 10**: Si el puntaje es ≥ 500, se aprueba sin calcular interés.
# - **Regla 11**: Si el ingreso mensual es mayor a 5 millones de pesos, se aprueba sin calcular interés.
#
# ## Reglas de Asignación de Interés
#
# - **Regla 12**: Si el crédito está aprobado y aún no tiene interés, se asigna un interés base según el riesgo y el puntaje.
# - **Regla 13**: Si riesgo < 0.3 y puntaje ≥ 800, se aplica un descuento de 2 puntos al interés.
# - **Regla 14**: Si se solicita > 50 millones de pesos y el riesgo es mayor a 0.5, se aplica un recargo de 2 puntos.
# - **Regla 15**: Si el plazo es corto (≤ 12 meses), se descuenta 1 punto del interés.
# - **Regla 16**: Si el monto solicitado es ≤ 5 millones de pesos, se descuenta 1.5 puntos por tratarse de microcrédito.
# - **Regla 17**: El interés se ajusta para que esté entre 5% y 20%.
#
# ## Regla de Revisión Final
#
# - **Regla 18**: Si no se cumple ninguna regla anterior, el crédito queda en estado "revisar" con interés 0.0.
#
# # 🧾 Explicación de los Hechos en el Sistema Experto
#
# En un sistema experto, los **hechos** (`Fact`) son unidades de conocimiento que representan información relevante del problema que se está resolviendo. Estos hechos sirven como entrada para las reglas del sistema.
#
# A continuación se explican los hechos utilizados en el sistema experto para evaluación de créditos:
#
#
# ## Hechos(FACT)
#
# ---
#
# ###  `PersonaFact`
#
# Representa los datos personales del solicitante del crédito.
#
# | Campo             | Tipo           | Descripción |
# |------------------|----------------|-------------|
# | `name`           | `str`          | Nombre de la persona. |
# | `anio_nacimiento`| `int`          | Año de nacimiento; útil para calcular la edad y validar si está en edad laboral. |
# | `riesgo_impago`  | `float` o `int`| Probabilidad estimada de que la persona no pague el crédito. Se usa para ajustar la tasa de interés. |
#
# ---
#
# ###  `IngresoFact`
#
# Contiene información sobre los ingresos del solicitante.
#
# | Campo    | Tipo           | Descripción |
# |----------|----------------|-------------|
# | `monto`  | `float` o `int`| Ingreso económico mensual o anual. Se utiliza para calcular la capacidad de pago. |
#
# ---
#
# ###  `HistorialFact`
#
# Describe el historial financiero del solicitante.
#
# | Campo                    | Tipo           | Descripción |
# |--------------------------|----------------|-------------|
# | `puntaje`                | `float` o `int`| Puntaje de crédito asignado por agencias financieras. |
# | `capacidad_endeudamiento`| `float` o `int`| Cuánto puede endeudarse según sus ingresos y deudas actuales. |
#
# ---
#
# ###  `CreditoFact`
#
# Define la solicitud de crédito realizada por la persona.
#
# | Campo       | Tipo           | Descripción |
# |-------------|----------------|-------------|
# | `solicitado`| `float` o `int`| Monto del crédito solicitado. |
# | `plazo`     | `int`          | Plazo en meses para devolver el crédito. |
# | `estado`    | `str`          | Estado actual de la solicitud (ej. `"pendiente"`, `"aprobado"`). |
#
# ---
#
# ## `ResultadoFact`
#
# Resultado del análisis y procesamiento de la solicitud. También incluye indicadores internos para controlar la lógica del sistema.
#
# | Campo                        | Tipo                        | Descripción |
# |-----------------------------|-----------------------------|-------------|
# | `aprobado`                  | `str`                       | Indica si el crédito fue aprobado (`"sí"` o `"no"`). |
# | `interes`                   | `float`, `int` o `None`     | Tasa de interés final asignada. |
# | `base_calculada`            | `bool`                      | Si ya se hizo el cálculo inicial de interés. |
# | `descuento_aplicado`        | `bool`                      | Si ya se aplicó un descuento por buen historial. |
# | `recargo_aplicado`          | `bool`                      | Si ya se aplicó un recargo por alto riesgo. |
# | `beneficio_plazo_corto_aplicado` | `bool`                | Si ya se aplicó una mejora por corto plazo de pago. |
# | `preferencial_aplicado`     | `bool`                      | Si ya se aplicaron condiciones especiales al solicitante. |
# | `microcredito_aplicado`     | `bool`                      | Si el sistema consideró la solicitud como un microcrédito. |
# | `clamp_aplicado`            | `bool`                      | Si ya se ajustó el interés dentro de los límites permitidos (5%-20%). |
#
# ---

# %%
# %pip install experta
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: experta in c:\users\d0ubt\appdata\roaming\python\python313\site-packages (1.9.4)
# Requirement already satisfied: frozendict==1.2 in c:\users\d0ubt\appdata\roaming\python\python313\site-packages (from experta) (1.2)
# Requirement already satisfied: schema==0.6.7 in c:\users\d0ubt\appdata\roaming\python\python313\site-packages (from experta) (0.6.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import collections.abc
if not hasattr(collections, 'Mapping'):
    collections.Mapping = collections.abc.Mapping
    
from experta import *
from schema import Or

# %%
# Para pruebas
import random

def calcular_interes(riesgo_impago, puntaje):
    interes = round(10 + (riesgo_impago * 10) - (puntaje * 0.01),2)
    return max(5, min(20, interes))


class PersonaFact(Fact):
    name = Field(str)
    anio_nacimiento = Field(int)
    riesgo_impago = Field(Or(float, int))


class IngresoFact(Fact):
    monto = Field(Or(float, int))


class HistorialFact(Fact):
    puntaje = Field(Or(float, int))
    capacidad_endeudamiento = Field(Or(float, int))


class CreditoFact(Fact):
    solicitado = Field(Or(float, int))
    plazo = Field(int)


class ResultadoFact(Fact):
    aprobado = Field(str)
    interes = Field(Or(float, int, None))

    # Variables para evitar bucles infinitos en calculo de interes 
    base_calculada = Field(bool, default=False)
    descuento_aplicado = Field(bool, default=False)
    recargo_aplicado = Field(bool, default=False)
    beneficio_plazo_corto_aplicado = Field(bool, default=False)
    preferencial_aplicado = Field(bool, default=False)
    microcredito_aplicado = Field(bool, default=False)
    clamp_aplicado = Field(bool, default=False)


class CreditEngine(KnowledgeEngine):
    
    # REGLAS DESAPROBAR CREDITO
    
    #Si es menor de edad, se deniega el credito
    @Rule(PersonaFact(anio_nacimiento=P(lambda anio: 2025 - anio < 18)),
          NOT(ResultadoFact()), salience=100)
    def menor_de_edad(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0, razon = 'Menor de edad'))

    #Si es muy mayor > 75, se deniega el credito
    @Rule(PersonaFact(anio_nacimiento=P(lambda anio: 2025 - anio > 75)),
          NOT(ResultadoFact()), salience=95)
    def mayor_senior(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0, razon = 'Muy mayor  de edad'))

    #Si el riesgo > 0.8, se deniega el credito
    @Rule(PersonaFact(riesgo_impago=P(lambda r: r > 0.8)),
          NOT(ResultadoFact()), salience=95)
    def riesgo_alto(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0, razon = 'Riesgo muy alto'))

    #Si gana menos de 1 millon de pesos, se deniega el credito
    @Rule(IngresoFact(monto=P(lambda p: p < 1)),
          NOT(ResultadoFact()), salience=90)
    def sueldo_bajo(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0,razon = 'Sueldo muy bajo'))

    #Si el puntaje crediticio < 300, se deniega el credito
    @Rule(HistorialFact(puntaje=P(lambda p: p < 300)),
          NOT(ResultadoFact()), salience=90)
    def historial_malo(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0, razon = 'Historial crediticio muy bajo'))

    #Si el credito solicitado > capacidad de endeudamiento, se deniega el creidto
    @Rule(HistorialFact(capacidad_endeudamiento=MATCH.cap),
          CreditoFact(solicitado=MATCH.sol, plazo=MATCH.plazo),
          TEST(lambda cap, sol, plazo: sol > cap ),
          NOT(ResultadoFact()), salience=90)
    def monto_excede_capacidad(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0, razon = 'Monto excede la capacidad de endeudamiento'))

    #Si el plazo del credito es mayor de 60 meses , se deniega el creidto
    @Rule(CreditoFact(plazo=P(lambda p: p > 60)),
          NOT(ResultadoFact()), salience=90)
    def plazo_extenso(self):
        self.declare(ResultadoFact(aprobado='no', interes=0.0,razon = 'Plazo muy extenso'))

    #REGLAS APROBAR CREDITO

    # Si el prestamo es menor de 10 millon de pesos, se aprueba el credito
    @Rule(CreditoFact(solicitado=P(lambda s: s <= 10)),
          NOT(ResultadoFact()), salience=85)
    def prestamo_pequeno(self):
        self.declare(ResultadoFact(aprobado='si', interes=0.0))

    #Si el riesgo de impago es menor del 50%, se aprueba el credito
    @Rule(PersonaFact(riesgo_impago=P(lambda r: r <= 0.5)),
          NOT(ResultadoFact()), salience=85)
    def riesgo_bajo_medio(self):
        self.declare(ResultadoFact(aprobado='si', interes=0.0))

    #Si puntaje creditio > 500, se aprueba el credito
    @Rule(HistorialFact(puntaje=P(lambda p: p >= 500)),
          NOT(ResultadoFact()), salience=85)
    def historial_bueno(self):
        self.declare(ResultadoFact(aprobado='si', interes=0.0))

    #Si ingreso > 5 millones de pesos, se aprueba el credito
    @Rule(IngresoFact(monto=P(lambda p: p >= 5)),
          NOT(ResultadoFact()), salience=80)
    def ingreso_suficiente(self):
        self.declare(ResultadoFact(aprobado='si', interes=0.0))

    # REGLAS CALCULO INTERES
    # Calcula el interes base con base a una formula
    @Rule(
        AS.res << ResultadoFact(aprobado='si', interes=0.0, base_calculada=False),
        PersonaFact(riesgo_impago=MATCH.riesgo),
        HistorialFact(puntaje=MATCH.puntaje),
        salience=70
    )
    def asignar_interes_base(self, res, riesgo, puntaje):
        base = calcular_interes(riesgo, puntaje)
        self.modify(res, interes=base, base_calculada=True)

    # Si puntaje crediticio alto y riesgo impago bajo, descuento interes
    @Rule(
        AS.res << ResultadoFact(aprobado='si', interes=MATCH.i, descuento_aplicado=False),
        PersonaFact(riesgo_impago=P(lambda r: r < 0.3)),
        HistorialFact(puntaje=P(lambda p: p >= 800)),
        salience=60
    )
    def descuento_excelente(self, res, i):
        self.modify(res, interes=max(5, i - 2), descuento_aplicado=True)

    #Si monto solicitado > 50 millones de pesos, aumento interes 
    @Rule(
        AS.res << ResultadoFact(aprobado='si', interes=MATCH.i, recargo_aplicado=False),
        CreditoFact(solicitado=P(lambda s: s > 50)),
        PersonaFact(riesgo_impago=P(lambda r: 0.4 < r )),
        salience=60
    )
    def recargo_monto_alto(self, res, i):
        self.modify(res, interes=min(20, i + 3), recargo_aplicado=True)

    #Si plazo menor a un año, descuento interes
    @Rule(
        AS.res << ResultadoFact(aprobado='si', interes=MATCH.i, beneficio_plazo_corto_aplicado=False),
        CreditoFact(plazo=P(lambda p: p <= 12)),
        salience=55
    )
    def beneficio_plazo_corto(self, res, i):
        self.modify(res, interes=max(5, i - 2), beneficio_plazo_corto_aplicado=True)

    #Si credito solicitado < 5 millones de pesos, descuento interes
    @Rule(
        AS.res << ResultadoFact(aprobado='si', interes=MATCH.i, microcredito_aplicado=False),
        CreditoFact(solicitado=P(lambda s: s <= 5)),
        salience=45
    )
    def microcredito(self, res, i):
        self.modify(res, interes=max(5, i - 1.5), microcredito_aplicado=True)

    #Interes min 5 y interes max 20
    @Rule(
        AS.res << ResultadoFact(aprobado='si', interes=MATCH.i, clamp_aplicado=False),
        salience=10
    )
    def interes_final(self, res, i):
        clamped = max(5, min(20, i))
        self.modify(res, interes=clamped, clamp_aplicado=True)

    # Si no se aplica ninguna regla, pendiente a revisar a la persona
    @Rule(NOT(ResultadoFact()), salience=0)
    def caso_default(self):
        self.declare(ResultadoFact(aprobado='revisar', interes=0.0))

engine = CreditEngine()
    
# Hacer pruebas
for i in range(100):
    engine.reset()
    name_persona = f'Ana {i}'
    
    anio_nacimiento = random.randint(1955, 2005)
    ingreso = random.randint(0, 3)
    puntaje = random.randint(0, 1000)
    capacidad_endeudamiento = round(random.uniform(1, 100), 2)
    solicitado = round(random.uniform(1, 40), 2)
    plazo = random.randint(1,60)
    estabilidad = round(random.uniform(0, 100), 2)
    riesgo_impago = sistema_difuso(ingreso, estabilidad, puntaje) / 100



    # Hechos de ejemplo
    engine.declare(PersonaFact(
        name=name_persona,
        anio_nacimiento=anio_nacimiento,
        riesgo_impago=riesgo_impago
    ))

    engine.declare(IngresoFact(monto=ingreso))

    engine.declare(HistorialFact(
        puntaje=puntaje,
        capacidad_endeudamiento=capacidad_endeudamiento
    ))

    engine.declare(CreditoFact(
        solicitado=solicitado,
        plazo=plazo,
        estado='nuevo'
    ))

    engine.run()
    resultados = [f for f in engine.facts.values() if isinstance(f, ResultadoFact)]
    ultimo = resultados[-1]
    print("Datos iniciales:")
    print(f"Nombre persona: {name_persona}")
    print(f"Año nacimiento: {anio_nacimiento}")
    print(f"Riesgo impago: {riesgo_impago}")
    print(f"Ingreso: {ingreso}")
    print(f"Puntaje: {puntaje}")
    print(f"Capacidad endeudamiento: {capacidad_endeudamiento}")
    print(f"Monto solicitado: {solicitado}")
    print(f"Plazo: {plazo} meses\n")
    print()

    aprobado_resultado = ultimo['aprobado']
    interes_resultado = ultimo['interes']
    
    if aprobado_resultado == 'si':
        print(f"Tu credito fue aprobado con interés: {ultimo['interes']}%")
        print()
    elif aprobado_resultado == 'no':
        razon = ultimo['razon']
        print('Tu credito no fue aprobado')
        print('Razon:', razon)
    else:
        print('No pudimos sacar una conclusion, revision manual')
    print()
# Out:
# Datos iniciales:
# Nombre persona: Ana 0
# Año nacimiento: 1969
# Riesgo impago: 0.029744028251391663
# Ingreso: 1
# Puntaje: 554
# Capacidad endeudamiento: 85.22
# Monto solicitado: 35.43
# Plazo: 18 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 1
# Año nacimiento: 1973
# Riesgo impago: 0.4605655244985781
# Ingreso: 3
# Puntaje: 184
# Capacidad endeudamiento: 31.26
# Monto solicitado: 21.8
# Plazo: 57 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 2
# Año nacimiento: 1971
# Riesgo impago: 0.09061500336540684
# Ingreso: 1
# Puntaje: 208
# Capacidad endeudamiento: 52.78
# Monto solicitado: 22.06
# Plazo: 58 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 3
# Año nacimiento: 1973
# Riesgo impago: 0.20470141750734105
# Ingreso: 2
# Puntaje: 232
# Capacidad endeudamiento: 53.8
# Monto solicitado: 26.71
# Plazo: 29 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 4
# Año nacimiento: 1987
# Riesgo impago: 0.3279077259212898
# Ingreso: 3
# Puntaje: 169
# Capacidad endeudamiento: 35.18
# Monto solicitado: 30.13
# Plazo: 50 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5
# Año nacimiento: 1998
# Riesgo impago: 0.3381673185716879
# Ingreso: 2
# Puntaje: 997
# Capacidad endeudamiento: 77.18
# Monto solicitado: 35.49
# Plazo: 32 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 6
# Año nacimiento: 2000
# Riesgo impago: 0.36340434810914857
# Ingreso: 2
# Puntaje: 828
# Capacidad endeudamiento: 45.96
# Monto solicitado: 6.2
# Plazo: 58 meses
#
#
# Tu credito fue aprobado con interés: 5.35%
#
#
# Datos iniciales:
# Nombre persona: Ana 7
# Año nacimiento: 1998
# Riesgo impago: 0.7456444629934101
# Ingreso: 1
# Puntaje: 99
# Capacidad endeudamiento: 24.26
# Monto solicitado: 35.58
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 8
# Año nacimiento: 1988
# Riesgo impago: 0.9170839552537098
# Ingreso: 3
# Puntaje: 863
# Capacidad endeudamiento: 68.92
# Monto solicitado: 25.0
# Plazo: 28 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 9
# Año nacimiento: 1970
# Riesgo impago: 0.09764606932633668
# Ingreso: 1
# Puntaje: 621
# Capacidad endeudamiento: 2.02
# Monto solicitado: 36.58
# Plazo: 54 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 10
# Año nacimiento: 1964
# Riesgo impago: 0.5109215508768344
# Ingreso: 3
# Puntaje: 425
# Capacidad endeudamiento: 13.79
# Monto solicitado: 6.35
# Plazo: 10 meses
#
#
# Tu credito fue aprobado con interés: 8.86%
#
#
# Datos iniciales:
# Nombre persona: Ana 11
# Año nacimiento: 1996
# Riesgo impago: 0.050887796497810056
# Ingreso: 1
# Puntaje: 681
# Capacidad endeudamiento: 60.7
# Monto solicitado: 1.03
# Plazo: 53 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 12
# Año nacimiento: 1963
# Riesgo impago: 0.8832076970232408
# Ingreso: 2
# Puntaje: 362
# Capacidad endeudamiento: 36.08
# Monto solicitado: 35.6
# Plazo: 29 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 13
# Año nacimiento: 1970
# Riesgo impago: 0.08802635747816001
# Ingreso: 0
# Puntaje: 148
# Capacidad endeudamiento: 6.75
# Monto solicitado: 39.63
# Plazo: 14 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 14
# Año nacimiento: 1980
# Riesgo impago: 0.12049334535214806
# Ingreso: 1
# Puntaje: 958
# Capacidad endeudamiento: 96.87
# Monto solicitado: 30.79
# Plazo: 38 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 15
# Año nacimiento: 1965
# Riesgo impago: 0.3512039349082339
# Ingreso: 1
# Puntaje: 9
# Capacidad endeudamiento: 39.37
# Monto solicitado: 26.44
# Plazo: 14 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 16
# Año nacimiento: 2002
# Riesgo impago: 0.724233527979976
# Ingreso: 2
# Puntaje: 85
# Capacidad endeudamiento: 57.58
# Monto solicitado: 35.46
# Plazo: 9 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 17
# Año nacimiento: 1989
# Riesgo impago: 0.10103867920943166
# Ingreso: 2
# Puntaje: 52
# Capacidad endeudamiento: 4.02
# Monto solicitado: 24.3
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 18
# Año nacimiento: 1976
# Riesgo impago: 0.782997745068187
# Ingreso: 1
# Puntaje: 75
# Capacidad endeudamiento: 85.71
# Monto solicitado: 30.49
# Plazo: 60 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 19
# Año nacimiento: 1985
# Riesgo impago: 0.17780432245329514
# Ingreso: 1
# Puntaje: 494
# Capacidad endeudamiento: 85.65
# Monto solicitado: 31.21
# Plazo: 48 meses
#
#
# Tu credito fue aprobado con interés: 6.84%
#
#
# Datos iniciales:
# Nombre persona: Ana 20
# Año nacimiento: 1960
# Riesgo impago: 0.5135781143959846
# Ingreso: 0
# Puntaje: 924
# Capacidad endeudamiento: 36.94
# Monto solicitado: 11.21
# Plazo: 4 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 21
# Año nacimiento: 1996
# Riesgo impago: 0.9901587927630314
# Ingreso: 3
# Puntaje: 699
# Capacidad endeudamiento: 13.32
# Monto solicitado: 33.7
# Plazo: 18 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 22
# Año nacimiento: 1994
# Riesgo impago: 0.6496285922478325
# Ingreso: 1
# Puntaje: 767
# Capacidad endeudamiento: 87.46
# Monto solicitado: 7.97
# Plazo: 46 meses
#
#
# Tu credito fue aprobado con interés: 8.83%
#
#
# Datos iniciales:
# Nombre persona: Ana 23
# Año nacimiento: 1983
# Riesgo impago: 0.19280235969660775
# Ingreso: 2
# Puntaje: 527
# Capacidad endeudamiento: 37.15
# Monto solicitado: 1.31
# Plazo: 16 meses
#
#
# Tu credito fue aprobado con interés: 5.16%
#
#
# Datos iniciales:
# Nombre persona: Ana 24
# Año nacimiento: 2003
# Riesgo impago: 0.9722825085638828
# Ingreso: 0
# Puntaje: 992
# Capacidad endeudamiento: 93.64
# Monto solicitado: 9.6
# Plazo: 14 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 25
# Año nacimiento: 1989
# Riesgo impago: 0.2459421736113374
# Ingreso: 1
# Puntaje: 556
# Capacidad endeudamiento: 77.58
# Monto solicitado: 34.82
# Plazo: 20 meses
#
#
# Tu credito fue aprobado con interés: 6.9%
#
#
# Datos iniciales:
# Nombre persona: Ana 26
# Año nacimiento: 1993
# Riesgo impago: 0.11963747369834564
# Ingreso: 0
# Puntaje: 213
# Capacidad endeudamiento: 1.31
# Monto solicitado: 34.61
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 27
# Año nacimiento: 2005
# Riesgo impago: 0.8025939399130813
# Ingreso: 3
# Puntaje: 888
# Capacidad endeudamiento: 70.57
# Monto solicitado: 6.6
# Plazo: 54 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 28
# Año nacimiento: 1961
# Riesgo impago: 0.6619984336391286
# Ingreso: 3
# Puntaje: 881
# Capacidad endeudamiento: 2.03
# Monto solicitado: 37.19
# Plazo: 60 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 29
# Año nacimiento: 1958
# Riesgo impago: 0.9524659753476102
# Ingreso: 2
# Puntaje: 944
# Capacidad endeudamiento: 7.79
# Monto solicitado: 26.78
# Plazo: 48 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 30
# Año nacimiento: 1967
# Riesgo impago: 0.013132053906638408
# Ingreso: 2
# Puntaje: 853
# Capacidad endeudamiento: 50.9
# Monto solicitado: 25.5
# Plazo: 42 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 31
# Año nacimiento: 1962
# Riesgo impago: 0.010034728881294974
# Ingreso: 2
# Puntaje: 974
# Capacidad endeudamiento: 97.75
# Monto solicitado: 32.51
# Plazo: 43 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 32
# Año nacimiento: 1964
# Riesgo impago: 0.6566527011934871
# Ingreso: 3
# Puntaje: 435
# Capacidad endeudamiento: 82.54
# Monto solicitado: 13.68
# Plazo: 46 meses
#
#
# No pudimos sacar una conclusion, revision manual
#
# Datos iniciales:
# Nombre persona: Ana 33
# Año nacimiento: 1970
# Riesgo impago: 0.5964984110726811
# Ingreso: 1
# Puntaje: 618
# Capacidad endeudamiento: 48.76
# Monto solicitado: 10.14
# Plazo: 6 meses
#
#
# Tu credito fue aprobado con interés: 7.779999999999999%
#
#
# Datos iniciales:
# Nombre persona: Ana 34
# Año nacimiento: 1962
# Riesgo impago: 0.5718705424657081
# Ingreso: 0
# Puntaje: 541
# Capacidad endeudamiento: 75.3
# Monto solicitado: 30.69
# Plazo: 50 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 35
# Año nacimiento: 1964
# Riesgo impago: 0.18346065468138006
# Ingreso: 2
# Puntaje: 702
# Capacidad endeudamiento: 47.24
# Monto solicitado: 13.01
# Plazo: 21 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 36
# Año nacimiento: 1976
# Riesgo impago: 0.6080229865657477
# Ingreso: 3
# Puntaje: 304
# Capacidad endeudamiento: 11.85
# Monto solicitado: 26.33
# Plazo: 38 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 37
# Año nacimiento: 1985
# Riesgo impago: 0.3206748572581538
# Ingreso: 2
# Puntaje: 934
# Capacidad endeudamiento: 23.14
# Monto solicitado: 7.6
# Plazo: 8 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 38
# Año nacimiento: 1993
# Riesgo impago: 0.5273082623140585
# Ingreso: 3
# Puntaje: 584
# Capacidad endeudamiento: 11.67
# Monto solicitado: 22.76
# Plazo: 52 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 39
# Año nacimiento: 1961
# Riesgo impago: 0.4052191105257381
# Ingreso: 2
# Puntaje: 631
# Capacidad endeudamiento: 31.22
# Monto solicitado: 14.72
# Plazo: 58 meses
#
#
# Tu credito fue aprobado con interés: 7.74%
#
#
# Datos iniciales:
# Nombre persona: Ana 40
# Año nacimiento: 2004
# Riesgo impago: 0.9287022123577745
# Ingreso: 3
# Puntaje: 503
# Capacidad endeudamiento: 2.21
# Monto solicitado: 30.28
# Plazo: 20 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 41
# Año nacimiento: 1992
# Riesgo impago: 0.8870002014083314
# Ingreso: 2
# Puntaje: 872
# Capacidad endeudamiento: 40.18
# Monto solicitado: 21.35
# Plazo: 38 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 42
# Año nacimiento: 1960
# Riesgo impago: 0.9771400898887092
# Ingreso: 2
# Puntaje: 58
# Capacidad endeudamiento: 84.65
# Monto solicitado: 31.19
# Plazo: 38 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 43
# Año nacimiento: 1962
# Riesgo impago: 0.9487359173518211
# Ingreso: 3
# Puntaje: 39
# Capacidad endeudamiento: 70.78
# Monto solicitado: 29.91
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 44
# Año nacimiento: 1997
# Riesgo impago: 0.4320719601613307
# Ingreso: 1
# Puntaje: 817
# Capacidad endeudamiento: 41.05
# Monto solicitado: 6.07
# Plazo: 41 meses
#
#
# Tu credito fue aprobado con interés: 6.15%
#
#
# Datos iniciales:
# Nombre persona: Ana 45
# Año nacimiento: 1963
# Riesgo impago: 0.26240250930494524
# Ingreso: 1
# Puntaje: 466
# Capacidad endeudamiento: 54.77
# Monto solicitado: 16.12
# Plazo: 38 meses
#
#
# Tu credito fue aprobado con interés: 7.96%
#
#
# Datos iniciales:
# Nombre persona: Ana 46
# Año nacimiento: 1969
# Riesgo impago: 0.09882789929734483
# Ingreso: 0
# Puntaje: 37
# Capacidad endeudamiento: 22.44
# Monto solicitado: 31.23
# Plazo: 41 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 47
# Año nacimiento: 1962
# Riesgo impago: 0.12186546499465656
# Ingreso: 1
# Puntaje: 501
# Capacidad endeudamiento: 97.31
# Monto solicitado: 6.81
# Plazo: 17 meses
#
#
# Tu credito fue aprobado con interés: 6.21%
#
#
# Datos iniciales:
# Nombre persona: Ana 48
# Año nacimiento: 1972
# Riesgo impago: 0.497379839351774
# Ingreso: 2
# Puntaje: 961
# Capacidad endeudamiento: 39.37
# Monto solicitado: 35.88
# Plazo: 24 meses
#
#
# Tu credito fue aprobado con interés: 5.36%
#
#
# Datos iniciales:
# Nombre persona: Ana 49
# Año nacimiento: 1963
# Riesgo impago: 0.4646972434886334
# Ingreso: 2
# Puntaje: 81
# Capacidad endeudamiento: 60.76
# Monto solicitado: 17.33
# Plazo: 27 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 50
# Año nacimiento: 1990
# Riesgo impago: 0.3285324946475805
# Ingreso: 2
# Puntaje: 191
# Capacidad endeudamiento: 45.25
# Monto solicitado: 38.1
# Plazo: 9 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 51
# Año nacimiento: 1958
# Riesgo impago: 0.22871230171783097
# Ingreso: 1
# Puntaje: 379
# Capacidad endeudamiento: 37.73
# Monto solicitado: 35.52
# Plazo: 22 meses
#
#
# Tu credito fue aprobado con interés: 8.5%
#
#
# Datos iniciales:
# Nombre persona: Ana 52
# Año nacimiento: 2000
# Riesgo impago: 0.157432273068843
# Ingreso: 3
# Puntaje: 789
# Capacidad endeudamiento: 29.57
# Monto solicitado: 39.04
# Plazo: 25 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 53
# Año nacimiento: 1987
# Riesgo impago: 0.8299587937127336
# Ingreso: 0
# Puntaje: 504
# Capacidad endeudamiento: 86.47
# Monto solicitado: 15.38
# Plazo: 32 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 54
# Año nacimiento: 1978
# Riesgo impago: 0.1937618241451522
# Ingreso: 1
# Puntaje: 530
# Capacidad endeudamiento: 52.96
# Monto solicitado: 14.0
# Plazo: 60 meses
#
#
# Tu credito fue aprobado con interés: 6.64%
#
#
# Datos iniciales:
# Nombre persona: Ana 55
# Año nacimiento: 1970
# Riesgo impago: 0.43360199252686593
# Ingreso: 0
# Puntaje: 32
# Capacidad endeudamiento: 79.83
# Monto solicitado: 20.18
# Plazo: 45 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 56
# Año nacimiento: 1959
# Riesgo impago: 0.325374691480389
# Ingreso: 2
# Puntaje: 872
# Capacidad endeudamiento: 39.92
# Monto solicitado: 8.7
# Plazo: 42 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 57
# Año nacimiento: 1957
# Riesgo impago: 0.8825639512309826
# Ingreso: 2
# Puntaje: 290
# Capacidad endeudamiento: 2.81
# Monto solicitado: 1.6
# Plazo: 26 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 58
# Año nacimiento: 1988
# Riesgo impago: 0.6207278056022107
# Ingreso: 1
# Puntaje: 245
# Capacidad endeudamiento: 96.11
# Monto solicitado: 21.36
# Plazo: 7 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 59
# Año nacimiento: 1992
# Riesgo impago: 0.40681687300543135
# Ingreso: 0
# Puntaje: 881
# Capacidad endeudamiento: 58.63
# Monto solicitado: 37.34
# Plazo: 54 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 60
# Año nacimiento: 2000
# Riesgo impago: 0.2567621292972663
# Ingreso: 2
# Puntaje: 975
# Capacidad endeudamiento: 14.29
# Monto solicitado: 6.65
# Plazo: 19 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 61
# Año nacimiento: 1986
# Riesgo impago: 0.6682725348518087
# Ingreso: 0
# Puntaje: 765
# Capacidad endeudamiento: 2.66
# Monto solicitado: 15.79
# Plazo: 46 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 62
# Año nacimiento: 2005
# Riesgo impago: 0.3584391765922671
# Ingreso: 3
# Puntaje: 363
# Capacidad endeudamiento: 43.46
# Monto solicitado: 39.54
# Plazo: 34 meses
#
#
# Tu credito fue aprobado con interés: 9.95%
#
#
# Datos iniciales:
# Nombre persona: Ana 63
# Año nacimiento: 2002
# Riesgo impago: 0.5337573798013281
# Ingreso: 3
# Puntaje: 438
# Capacidad endeudamiento: 3.39
# Monto solicitado: 20.34
# Plazo: 14 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 64
# Año nacimiento: 2002
# Riesgo impago: 0.6877859626626004
# Ingreso: 3
# Puntaje: 896
# Capacidad endeudamiento: 95.97
# Monto solicitado: 11.43
# Plazo: 55 meses
#
#
# Tu credito fue aprobado con interés: 7.92%
#
#
# Datos iniciales:
# Nombre persona: Ana 65
# Año nacimiento: 1977
# Riesgo impago: 0.2036016885795101
# Ingreso: 1
# Puntaje: 755
# Capacidad endeudamiento: 66.52
# Monto solicitado: 14.07
# Plazo: 53 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 66
# Año nacimiento: 1969
# Riesgo impago: 0.3307551124281638
# Ingreso: 3
# Puntaje: 961
# Capacidad endeudamiento: 88.37
# Monto solicitado: 39.99
# Plazo: 28 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 67
# Año nacimiento: 1957
# Riesgo impago: 0.008207378950654043
# Ingreso: 2
# Puntaje: 315
# Capacidad endeudamiento: 11.82
# Monto solicitado: 21.61
# Plazo: 21 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 68
# Año nacimiento: 1988
# Riesgo impago: 0.08809242665655648
# Ingreso: 3
# Puntaje: 124
# Capacidad endeudamiento: 70.74
# Monto solicitado: 28.21
# Plazo: 40 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 69
# Año nacimiento: 1964
# Riesgo impago: 0.3244816798296075
# Ingreso: 0
# Puntaje: 502
# Capacidad endeudamiento: 95.82
# Monto solicitado: 26.41
# Plazo: 42 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 70
# Año nacimiento: 1957
# Riesgo impago: 0.15621280959350947
# Ingreso: 1
# Puntaje: 258
# Capacidad endeudamiento: 97.24
# Monto solicitado: 1.76
# Plazo: 25 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 71
# Año nacimiento: 2002
# Riesgo impago: 0.08941499788903172
# Ingreso: 1
# Puntaje: 190
# Capacidad endeudamiento: 7.68
# Monto solicitado: 9.2
# Plazo: 35 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 72
# Año nacimiento: 1984
# Riesgo impago: 0.48935775511205987
# Ingreso: 2
# Puntaje: 273
# Capacidad endeudamiento: 92.41
# Monto solicitado: 22.01
# Plazo: 48 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 73
# Año nacimiento: 1979
# Riesgo impago: 0.7925656778234617
# Ingreso: 1
# Puntaje: 129
# Capacidad endeudamiento: 29.5
# Monto solicitado: 37.31
# Plazo: 29 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 74
# Año nacimiento: 1999
# Riesgo impago: 0.6211541613949002
# Ingreso: 2
# Puntaje: 716
# Capacidad endeudamiento: 38.18
# Monto solicitado: 2.67
# Plazo: 41 meses
#
#
# Tu credito fue aprobado con interés: 7.550000000000001%
#
#
# Datos iniciales:
# Nombre persona: Ana 75
# Año nacimiento: 1962
# Riesgo impago: 0.19315931551925425
# Ingreso: 3
# Puntaje: 33
# Capacidad endeudamiento: 10.31
# Monto solicitado: 29.61
# Plazo: 24 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 76
# Año nacimiento: 1967
# Riesgo impago: 0.7050794101985609
# Ingreso: 0
# Puntaje: 440
# Capacidad endeudamiento: 25.71
# Monto solicitado: 14.7
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 77
# Año nacimiento: 1981
# Riesgo impago: 0.4055078833468669
# Ingreso: 2
# Puntaje: 425
# Capacidad endeudamiento: 26.49
# Monto solicitado: 36.54
# Plazo: 7 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 78
# Año nacimiento: 1970
# Riesgo impago: 0.17330570897431363
# Ingreso: 3
# Puntaje: 549
# Capacidad endeudamiento: 40.39
# Monto solicitado: 30.46
# Plazo: 42 meses
#
#
# Tu credito fue aprobado con interés: 6.24%
#
#
# Datos iniciales:
# Nombre persona: Ana 79
# Año nacimiento: 2005
# Riesgo impago: 0.9525816542118306
# Ingreso: 1
# Puntaje: 165
# Capacidad endeudamiento: 37.84
# Monto solicitado: 36.97
# Plazo: 3 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 80
# Año nacimiento: 1980
# Riesgo impago: 0.5175595936539938
# Ingreso: 1
# Puntaje: 546
# Capacidad endeudamiento: 36.14
# Monto solicitado: 23.23
# Plazo: 47 meses
#
#
# Tu credito fue aprobado con interés: 9.72%
#
#
# Datos iniciales:
# Nombre persona: Ana 81
# Año nacimiento: 1966
# Riesgo impago: 0.9152915453971789
# Ingreso: 1
# Puntaje: 792
# Capacidad endeudamiento: 82.28
# Monto solicitado: 27.9
# Plazo: 15 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 82
# Año nacimiento: 1970
# Riesgo impago: 0.38855833645108495
# Ingreso: 3
# Puntaje: 65
# Capacidad endeudamiento: 19.45
# Monto solicitado: 32.14
# Plazo: 25 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 83
# Año nacimiento: 2002
# Riesgo impago: 0.3587887185143096
# Ingreso: 3
# Puntaje: 194
# Capacidad endeudamiento: 67.19
# Monto solicitado: 14.28
# Plazo: 48 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 84
# Año nacimiento: 1991
# Riesgo impago: 0.1310985579620566
# Ingreso: 2
# Puntaje: 745
# Capacidad endeudamiento: 75.51
# Monto solicitado: 32.9
# Plazo: 20 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 85
# Año nacimiento: 1978
# Riesgo impago: 0.7074520049002655
# Ingreso: 3
# Puntaje: 90
# Capacidad endeudamiento: 81.04
# Monto solicitado: 25.28
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 86
# Año nacimiento: 1992
# Riesgo impago: 0.366868520562032
# Ingreso: 3
# Puntaje: 919
# Capacidad endeudamiento: 14.99
# Monto solicitado: 29.29
# Plazo: 35 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 87
# Año nacimiento: 1976
# Riesgo impago: 0.09382488827073743
# Ingreso: 3
# Puntaje: 0
# Capacidad endeudamiento: 84.35
# Monto solicitado: 11.08
# Plazo: 31 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 88
# Año nacimiento: 1984
# Riesgo impago: 0.9465711565894948
# Ingreso: 0
# Puntaje: 316
# Capacidad endeudamiento: 61.84
# Monto solicitado: 2.61
# Plazo: 53 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 89
# Año nacimiento: 1985
# Riesgo impago: 0.7741150430069331
# Ingreso: 3
# Puntaje: 116
# Capacidad endeudamiento: 78.04
# Monto solicitado: 12.11
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 90
# Año nacimiento: 1973
# Riesgo impago: 0.6882225243549314
# Ingreso: 3
# Puntaje: 352
# Capacidad endeudamiento: 84.26
# Monto solicitado: 35.56
# Plazo: 51 meses
#
#
# No pudimos sacar una conclusion, revision manual
#
# Datos iniciales:
# Nombre persona: Ana 91
# Año nacimiento: 2005
# Riesgo impago: 0.16363617118674612
# Ingreso: 0
# Puntaje: 146
# Capacidad endeudamiento: 54.9
# Monto solicitado: 37.21
# Plazo: 56 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 92
# Año nacimiento: 1977
# Riesgo impago: 0.8178092087054839
# Ingreso: 0
# Puntaje: 340
# Capacidad endeudamiento: 92.88
# Monto solicitado: 38.96
# Plazo: 42 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 93
# Año nacimiento: 1990
# Riesgo impago: 0.9405181311701116
# Ingreso: 2
# Puntaje: 341
# Capacidad endeudamiento: 15.27
# Monto solicitado: 11.47
# Plazo: 38 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 94
# Año nacimiento: 1989
# Riesgo impago: 0.9312741383566704
# Ingreso: 1
# Puntaje: 178
# Capacidad endeudamiento: 33.4
# Monto solicitado: 39.53
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 95
# Año nacimiento: 1990
# Riesgo impago: 0.9980522405528559
# Ingreso: 0
# Puntaje: 628
# Capacidad endeudamiento: 99.51
# Monto solicitado: 19.36
# Plazo: 15 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 96
# Año nacimiento: 1996
# Riesgo impago: 0.4294088886730002
# Ingreso: 0
# Puntaje: 65
# Capacidad endeudamiento: 3.53
# Monto solicitado: 2.85
# Plazo: 28 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 97
# Año nacimiento: 1984
# Riesgo impago: 0.024640500752990402
# Ingreso: 1
# Puntaje: 83
# Capacidad endeudamiento: 89.69
# Monto solicitado: 26.39
# Plazo: 10 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 98
# Año nacimiento: 1982
# Riesgo impago: 0.2424008349786737
# Ingreso: 0
# Puntaje: 867
# Capacidad endeudamiento: 74.34
# Monto solicitado: 12.15
# Plazo: 51 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 99
# Año nacimiento: 1989
# Riesgo impago: 0.22857127558097168
# Ingreso: 1
# Puntaje: 681
# Capacidad endeudamiento: 23.16
# Monto solicitado: 21.91
# Plazo: 15 meses
#
#
# Tu credito fue aprobado con interés: 5.48%
#
#
# Datos iniciales:
# Nombre persona: Ana 100
# Año nacimiento: 1988
# Riesgo impago: 0.6125880605660621
# Ingreso: 1
# Puntaje: 952
# Capacidad endeudamiento: 88.88
# Monto solicitado: 20.78
# Plazo: 3 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 101
# Año nacimiento: 2005
# Riesgo impago: 0.7205392658258839
# Ingreso: 3
# Puntaje: 785
# Capacidad endeudamiento: 84.11
# Monto solicitado: 22.34
# Plazo: 39 meses
#
#
# Tu credito fue aprobado con interés: 9.36%
#
#
# Datos iniciales:
# Nombre persona: Ana 102
# Año nacimiento: 2001
# Riesgo impago: 0.2899625568023697
# Ingreso: 1
# Puntaje: 234
# Capacidad endeudamiento: 69.73
# Monto solicitado: 4.5
# Plazo: 57 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 103
# Año nacimiento: 1977
# Riesgo impago: 0.9516119847015791
# Ingreso: 1
# Puntaje: 160
# Capacidad endeudamiento: 85.15
# Monto solicitado: 16.57
# Plazo: 51 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 104
# Año nacimiento: 1955
# Riesgo impago: 0.13105583374801466
# Ingreso: 2
# Puntaje: 364
# Capacidad endeudamiento: 83.85
# Monto solicitado: 11.42
# Plazo: 21 meses
#
#
# Tu credito fue aprobado con interés: 7.67%
#
#
# Datos iniciales:
# Nombre persona: Ana 105
# Año nacimiento: 1994
# Riesgo impago: 0.4854773878611029
# Ingreso: 2
# Puntaje: 309
# Capacidad endeudamiento: 60.59
# Monto solicitado: 34.56
# Plazo: 31 meses
#
#
# Tu credito fue aprobado con interés: 11.76%
#
#
# Datos iniciales:
# Nombre persona: Ana 106
# Año nacimiento: 1991
# Riesgo impago: 0.6279399291343604
# Ingreso: 1
# Puntaje: 192
# Capacidad endeudamiento: 34.59
# Monto solicitado: 27.13
# Plazo: 19 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 107
# Año nacimiento: 1957
# Riesgo impago: 0.6502306671238052
# Ingreso: 1
# Puntaje: 526
# Capacidad endeudamiento: 58.37
# Monto solicitado: 29.67
# Plazo: 36 meses
#
#
# Tu credito fue aprobado con interés: 11.24%
#
#
# Datos iniciales:
# Nombre persona: Ana 108
# Año nacimiento: 1970
# Riesgo impago: 0.6308120317900417
# Ingreso: 1
# Puntaje: 567
# Capacidad endeudamiento: 91.42
# Monto solicitado: 6.98
# Plazo: 8 meses
#
#
# Tu credito fue aprobado con interés: 8.64%
#
#
# Datos iniciales:
# Nombre persona: Ana 109
# Año nacimiento: 1989
# Riesgo impago: 0.99326640782355
# Ingreso: 3
# Puntaje: 74
# Capacidad endeudamiento: 14.05
# Monto solicitado: 9.47
# Plazo: 50 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 110
# Año nacimiento: 2004
# Riesgo impago: 0.2212271995334214
# Ingreso: 2
# Puntaje: 928
# Capacidad endeudamiento: 98.63
# Monto solicitado: 8.93
# Plazo: 10 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 111
# Año nacimiento: 1970
# Riesgo impago: 0.8361634000325857
# Ingreso: 0
# Puntaje: 713
# Capacidad endeudamiento: 32.52
# Monto solicitado: 7.27
# Plazo: 24 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 112
# Año nacimiento: 1970
# Riesgo impago: 0.6452798689798156
# Ingreso: 2
# Puntaje: 911
# Capacidad endeudamiento: 12.58
# Monto solicitado: 19.95
# Plazo: 57 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 113
# Año nacimiento: 1967
# Riesgo impago: 0.45933622874895813
# Ingreso: 0
# Puntaje: 453
# Capacidad endeudamiento: 45.86
# Monto solicitado: 24.41
# Plazo: 8 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 114
# Año nacimiento: 1987
# Riesgo impago: 0.9599173939229588
# Ingreso: 3
# Puntaje: 661
# Capacidad endeudamiento: 49.78
# Monto solicitado: 37.07
# Plazo: 26 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 115
# Año nacimiento: 1965
# Riesgo impago: 0.1548763539138135
# Ingreso: 0
# Puntaje: 392
# Capacidad endeudamiento: 66.65
# Monto solicitado: 13.35
# Plazo: 19 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 116
# Año nacimiento: 1987
# Riesgo impago: 0.2812066528351925
# Ingreso: 2
# Puntaje: 537
# Capacidad endeudamiento: 65.16
# Monto solicitado: 2.87
# Plazo: 45 meses
#
#
# Tu credito fue aprobado con interés: 5.94%
#
#
# Datos iniciales:
# Nombre persona: Ana 117
# Año nacimiento: 1962
# Riesgo impago: 0.11922858810739022
# Ingreso: 2
# Puntaje: 269
# Capacidad endeudamiento: 13.64
# Monto solicitado: 34.51
# Plazo: 47 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 118
# Año nacimiento: 1995
# Riesgo impago: 0.03322513803967253
# Ingreso: 3
# Puntaje: 564
# Capacidad endeudamiento: 79.54
# Monto solicitado: 25.39
# Plazo: 54 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 119
# Año nacimiento: 1955
# Riesgo impago: 0.06986653855925384
# Ingreso: 0
# Puntaje: 489
# Capacidad endeudamiento: 33.52
# Monto solicitado: 13.85
# Plazo: 40 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 120
# Año nacimiento: 1976
# Riesgo impago: 0.7333961482395469
# Ingreso: 0
# Puntaje: 533
# Capacidad endeudamiento: 29.94
# Monto solicitado: 5.21
# Plazo: 46 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 121
# Año nacimiento: 1962
# Riesgo impago: 0.7364514073305432
# Ingreso: 1
# Puntaje: 39
# Capacidad endeudamiento: 55.78
# Monto solicitado: 4.19
# Plazo: 52 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 122
# Año nacimiento: 1994
# Riesgo impago: 0.7027354904564929
# Ingreso: 2
# Puntaje: 732
# Capacidad endeudamiento: 52.46
# Monto solicitado: 14.2
# Plazo: 49 meses
#
#
# Tu credito fue aprobado con interés: 9.71%
#
#
# Datos iniciales:
# Nombre persona: Ana 123
# Año nacimiento: 1966
# Riesgo impago: 0.05729139120092153
# Ingreso: 1
# Puntaje: 838
# Capacidad endeudamiento: 44.31
# Monto solicitado: 37.28
# Plazo: 42 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 124
# Año nacimiento: 1993
# Riesgo impago: 0.6535695524810194
# Ingreso: 0
# Puntaje: 606
# Capacidad endeudamiento: 43.38
# Monto solicitado: 36.79
# Plazo: 57 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 125
# Año nacimiento: 1987
# Riesgo impago: 0.24728386336874686
# Ingreso: 1
# Puntaje: 612
# Capacidad endeudamiento: 33.81
# Monto solicitado: 33.1
# Plazo: 55 meses
#
#
# Tu credito fue aprobado con interés: 6.35%
#
#
# Datos iniciales:
# Nombre persona: Ana 126
# Año nacimiento: 1978
# Riesgo impago: 0.6819156750985073
# Ingreso: 1
# Puntaje: 198
# Capacidad endeudamiento: 54.8
# Monto solicitado: 3.26
# Plazo: 29 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 127
# Año nacimiento: 1997
# Riesgo impago: 0.802331721913541
# Ingreso: 0
# Puntaje: 854
# Capacidad endeudamiento: 39.32
# Monto solicitado: 27.98
# Plazo: 5 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 128
# Año nacimiento: 1978
# Riesgo impago: 0.30509164517584286
# Ingreso: 1
# Puntaje: 760
# Capacidad endeudamiento: 38.8
# Monto solicitado: 11.29
# Plazo: 7 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 129
# Año nacimiento: 1967
# Riesgo impago: 0.38762546518236074
# Ingreso: 0
# Puntaje: 830
# Capacidad endeudamiento: 65.23
# Monto solicitado: 38.8
# Plazo: 55 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 130
# Año nacimiento: 1984
# Riesgo impago: 0.32178805845753244
# Ingreso: 0
# Puntaje: 573
# Capacidad endeudamiento: 34.29
# Monto solicitado: 33.63
# Plazo: 54 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 131
# Año nacimiento: 1965
# Riesgo impago: 0.1903338763412309
# Ingreso: 0
# Puntaje: 594
# Capacidad endeudamiento: 53.82
# Monto solicitado: 24.78
# Plazo: 47 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 132
# Año nacimiento: 1978
# Riesgo impago: 0.449251203246012
# Ingreso: 2
# Puntaje: 329
# Capacidad endeudamiento: 10.04
# Monto solicitado: 26.85
# Plazo: 44 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 133
# Año nacimiento: 2001
# Riesgo impago: 0.18962951926437022
# Ingreso: 3
# Puntaje: 278
# Capacidad endeudamiento: 11.92
# Monto solicitado: 16.38
# Plazo: 34 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 134
# Año nacimiento: 1987
# Riesgo impago: 0.9643383386510996
# Ingreso: 2
# Puntaje: 476
# Capacidad endeudamiento: 67.64
# Monto solicitado: 15.18
# Plazo: 6 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 135
# Año nacimiento: 1978
# Riesgo impago: 0.39812217095915536
# Ingreso: 2
# Puntaje: 28
# Capacidad endeudamiento: 91.78
# Monto solicitado: 29.68
# Plazo: 43 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 136
# Año nacimiento: 1966
# Riesgo impago: 0.8202327580259511
# Ingreso: 3
# Puntaje: 315
# Capacidad endeudamiento: 90.59
# Monto solicitado: 28.31
# Plazo: 49 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 137
# Año nacimiento: 1996
# Riesgo impago: 0.018658595437785253
# Ingreso: 1
# Puntaje: 333
# Capacidad endeudamiento: 3.45
# Monto solicitado: 36.13
# Plazo: 56 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 138
# Año nacimiento: 1996
# Riesgo impago: 0.9305249849876954
# Ingreso: 1
# Puntaje: 648
# Capacidad endeudamiento: 18.5
# Monto solicitado: 5.62
# Plazo: 15 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 139
# Año nacimiento: 1989
# Riesgo impago: 0.7290411928201492
# Ingreso: 3
# Puntaje: 902
# Capacidad endeudamiento: 96.28
# Monto solicitado: 2.35
# Plazo: 7 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 140
# Año nacimiento: 1981
# Riesgo impago: 0.02715487644821757
# Ingreso: 0
# Puntaje: 752
# Capacidad endeudamiento: 36.79
# Monto solicitado: 7.65
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 141
# Año nacimiento: 1987
# Riesgo impago: 0.4328403829519482
# Ingreso: 0
# Puntaje: 655
# Capacidad endeudamiento: 27.72
# Monto solicitado: 23.38
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 142
# Año nacimiento: 1985
# Riesgo impago: 0.4292721632927684
# Ingreso: 1
# Puntaje: 622
# Capacidad endeudamiento: 16.0
# Monto solicitado: 20.19
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 143
# Año nacimiento: 1979
# Riesgo impago: 0.45634580777992506
# Ingreso: 2
# Puntaje: 437
# Capacidad endeudamiento: 22.51
# Monto solicitado: 26.05
# Plazo: 31 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 144
# Año nacimiento: 1991
# Riesgo impago: 0.14832277305877817
# Ingreso: 1
# Puntaje: 718
# Capacidad endeudamiento: 6.44
# Monto solicitado: 33.1
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 145
# Año nacimiento: 1956
# Riesgo impago: 0.3189886804166737
# Ingreso: 0
# Puntaje: 880
# Capacidad endeudamiento: 4.34
# Monto solicitado: 17.46
# Plazo: 40 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 146
# Año nacimiento: 1971
# Riesgo impago: 0.5406028423402698
# Ingreso: 3
# Puntaje: 238
# Capacidad endeudamiento: 32.06
# Monto solicitado: 11.88
# Plazo: 50 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 147
# Año nacimiento: 2002
# Riesgo impago: 0.260013335840684
# Ingreso: 0
# Puntaje: 652
# Capacidad endeudamiento: 13.99
# Monto solicitado: 22.28
# Plazo: 43 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 148
# Año nacimiento: 1997
# Riesgo impago: 0.370556005453339
# Ingreso: 0
# Puntaje: 872
# Capacidad endeudamiento: 81.98
# Monto solicitado: 17.68
# Plazo: 49 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 149
# Año nacimiento: 1976
# Riesgo impago: 0.12968017029786283
# Ingreso: 0
# Puntaje: 608
# Capacidad endeudamiento: 49.83
# Monto solicitado: 6.06
# Plazo: 26 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 150
# Año nacimiento: 1971
# Riesgo impago: 0.5558832664851957
# Ingreso: 2
# Puntaje: 913
# Capacidad endeudamiento: 38.22
# Monto solicitado: 13.11
# Plazo: 45 meses
#
#
# Tu credito fue aprobado con interés: 6.43%
#
#
# Datos iniciales:
# Nombre persona: Ana 151
# Año nacimiento: 1956
# Riesgo impago: 0.9009981708890085
# Ingreso: 1
# Puntaje: 148
# Capacidad endeudamiento: 99.7
# Monto solicitado: 34.07
# Plazo: 53 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 152
# Año nacimiento: 1975
# Riesgo impago: 0.8497650651463141
# Ingreso: 0
# Puntaje: 657
# Capacidad endeudamiento: 69.01
# Monto solicitado: 34.48
# Plazo: 10 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 153
# Año nacimiento: 2004
# Riesgo impago: 0.5526226165918995
# Ingreso: 0
# Puntaje: 722
# Capacidad endeudamiento: 65.98
# Monto solicitado: 26.25
# Plazo: 60 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 154
# Año nacimiento: 1970
# Riesgo impago: 0.975591297581429
# Ingreso: 3
# Puntaje: 655
# Capacidad endeudamiento: 67.17
# Monto solicitado: 29.25
# Plazo: 20 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 155
# Año nacimiento: 1993
# Riesgo impago: 0.06060337251442805
# Ingreso: 0
# Puntaje: 449
# Capacidad endeudamiento: 87.66
# Monto solicitado: 1.2
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 156
# Año nacimiento: 1957
# Riesgo impago: 0.44448898538724946
# Ingreso: 3
# Puntaje: 261
# Capacidad endeudamiento: 58.01
# Monto solicitado: 39.24
# Plazo: 51 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 157
# Año nacimiento: 1979
# Riesgo impago: 0.897982543902927
# Ingreso: 3
# Puntaje: 827
# Capacidad endeudamiento: 44.85
# Monto solicitado: 3.64
# Plazo: 35 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 158
# Año nacimiento: 1991
# Riesgo impago: 0.08457353378706234
# Ingreso: 0
# Puntaje: 94
# Capacidad endeudamiento: 12.09
# Monto solicitado: 17.15
# Plazo: 46 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 159
# Año nacimiento: 1989
# Riesgo impago: 0.7908428200234171
# Ingreso: 3
# Puntaje: 573
# Capacidad endeudamiento: 15.99
# Monto solicitado: 14.72
# Plazo: 52 meses
#
#
# Tu credito fue aprobado con interés: 12.18%
#
#
# Datos iniciales:
# Nombre persona: Ana 160
# Año nacimiento: 1990
# Riesgo impago: 0.2754017285331485
# Ingreso: 2
# Puntaje: 863
# Capacidad endeudamiento: 49.09
# Monto solicitado: 2.95
# Plazo: 10 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 161
# Año nacimiento: 1977
# Riesgo impago: 0.29117697365157813
# Ingreso: 1
# Puntaje: 450
# Capacidad endeudamiento: 71.03
# Monto solicitado: 20.57
# Plazo: 17 meses
#
#
# Tu credito fue aprobado con interés: 8.41%
#
#
# Datos iniciales:
# Nombre persona: Ana 162
# Año nacimiento: 2003
# Riesgo impago: 0.07348941824800115
# Ingreso: 0
# Puntaje: 369
# Capacidad endeudamiento: 24.66
# Monto solicitado: 11.64
# Plazo: 32 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 163
# Año nacimiento: 2002
# Riesgo impago: 0.8537945120061078
# Ingreso: 3
# Puntaje: 257
# Capacidad endeudamiento: 17.71
# Monto solicitado: 19.62
# Plazo: 23 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 164
# Año nacimiento: 2002
# Riesgo impago: 0.05301871226185185
# Ingreso: 2
# Puntaje: 203
# Capacidad endeudamiento: 41.77
# Monto solicitado: 36.28
# Plazo: 10 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 165
# Año nacimiento: 1998
# Riesgo impago: 0.015605147846310286
# Ingreso: 3
# Puntaje: 306
# Capacidad endeudamiento: 77.66
# Monto solicitado: 34.7
# Plazo: 17 meses
#
#
# Tu credito fue aprobado con interés: 7.1%
#
#
# Datos iniciales:
# Nombre persona: Ana 166
# Año nacimiento: 1986
# Riesgo impago: 0.15880657244360263
# Ingreso: 0
# Puntaje: 73
# Capacidad endeudamiento: 93.83
# Monto solicitado: 9.24
# Plazo: 59 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 167
# Año nacimiento: 1957
# Riesgo impago: 0.05037509889826164
# Ingreso: 2
# Puntaje: 305
# Capacidad endeudamiento: 62.7
# Monto solicitado: 14.77
# Plazo: 53 meses
#
#
# Tu credito fue aprobado con interés: 7.45%
#
#
# Datos iniciales:
# Nombre persona: Ana 168
# Año nacimiento: 1977
# Riesgo impago: 0.6898456910621836
# Ingreso: 3
# Puntaje: 534
# Capacidad endeudamiento: 89.22
# Monto solicitado: 27.32
# Plazo: 29 meses
#
#
# Tu credito fue aprobado con interés: 11.56%
#
#
# Datos iniciales:
# Nombre persona: Ana 169
# Año nacimiento: 2004
# Riesgo impago: 0.3951623701427314
# Ingreso: 0
# Puntaje: 639
# Capacidad endeudamiento: 51.84
# Monto solicitado: 29.85
# Plazo: 22 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 170
# Año nacimiento: 1962
# Riesgo impago: 0.7210860471048277
# Ingreso: 0
# Puntaje: 966
# Capacidad endeudamiento: 81.49
# Monto solicitado: 30.63
# Plazo: 37 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 171
# Año nacimiento: 1994
# Riesgo impago: 0.39893918795575123
# Ingreso: 0
# Puntaje: 860
# Capacidad endeudamiento: 5.68
# Monto solicitado: 37.45
# Plazo: 49 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 172
# Año nacimiento: 1996
# Riesgo impago: 0.39551111656419713
# Ingreso: 0
# Puntaje: 162
# Capacidad endeudamiento: 56.5
# Monto solicitado: 32.38
# Plazo: 18 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 173
# Año nacimiento: 1977
# Riesgo impago: 0.8165222937914691
# Ingreso: 1
# Puntaje: 708
# Capacidad endeudamiento: 49.18
# Monto solicitado: 22.81
# Plazo: 6 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 174
# Año nacimiento: 1989
# Riesgo impago: 0.6195767755957506
# Ingreso: 1
# Puntaje: 288
# Capacidad endeudamiento: 72.19
# Monto solicitado: 19.97
# Plazo: 58 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 175
# Año nacimiento: 1978
# Riesgo impago: 0.4147452305343735
# Ingreso: 1
# Puntaje: 313
# Capacidad endeudamiento: 79.13
# Monto solicitado: 38.08
# Plazo: 40 meses
#
#
# Tu credito fue aprobado con interés: 11.02%
#
#
# Datos iniciales:
# Nombre persona: Ana 176
# Año nacimiento: 1972
# Riesgo impago: 0.29464671661377995
# Ingreso: 3
# Puntaje: 914
# Capacidad endeudamiento: 18.42
# Monto solicitado: 35.89
# Plazo: 46 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 177
# Año nacimiento: 1996
# Riesgo impago: 0.6880499898168045
# Ingreso: 3
# Puntaje: 531
# Capacidad endeudamiento: 4.06
# Monto solicitado: 38.83
# Plazo: 51 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 178
# Año nacimiento: 2004
# Riesgo impago: 0.977528827234525
# Ingreso: 0
# Puntaje: 227
# Capacidad endeudamiento: 57.48
# Monto solicitado: 1.06
# Plazo: 8 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 179
# Año nacimiento: 1972
# Riesgo impago: 0.5374475882635381
# Ingreso: 1
# Puntaje: 111
# Capacidad endeudamiento: 54.9
# Monto solicitado: 1.6
# Plazo: 32 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 180
# Año nacimiento: 1999
# Riesgo impago: 0.2446346500980352
# Ingreso: 1
# Puntaje: 211
# Capacidad endeudamiento: 40.93
# Monto solicitado: 19.75
# Plazo: 57 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 181
# Año nacimiento: 1990
# Riesgo impago: 0.34150368302190676
# Ingreso: 1
# Puntaje: 174
# Capacidad endeudamiento: 26.91
# Monto solicitado: 30.64
# Plazo: 28 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 182
# Año nacimiento: 2001
# Riesgo impago: 0.9758582447831201
# Ingreso: 3
# Puntaje: 695
# Capacidad endeudamiento: 37.58
# Monto solicitado: 19.69
# Plazo: 16 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 183
# Año nacimiento: 1989
# Riesgo impago: 0.08460479359465267
# Ingreso: 3
# Puntaje: 96
# Capacidad endeudamiento: 92.41
# Monto solicitado: 10.64
# Plazo: 40 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 184
# Año nacimiento: 1989
# Riesgo impago: 0.00166781394896387
# Ingreso: 2
# Puntaje: 672
# Capacidad endeudamiento: 92.52
# Monto solicitado: 29.78
# Plazo: 42 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 185
# Año nacimiento: 2003
# Riesgo impago: 0.15727973625092273
# Ingreso: 2
# Puntaje: 115
# Capacidad endeudamiento: 96.11
# Monto solicitado: 4.91
# Plazo: 30 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 186
# Año nacimiento: 1983
# Riesgo impago: 0.8923204221704176
# Ingreso: 3
# Puntaje: 441
# Capacidad endeudamiento: 40.74
# Monto solicitado: 10.9
# Plazo: 9 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 187
# Año nacimiento: 2001
# Riesgo impago: 0.44688547660462996
# Ingreso: 1
# Puntaje: 136
# Capacidad endeudamiento: 16.66
# Monto solicitado: 37.1
# Plazo: 47 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 188
# Año nacimiento: 1966
# Riesgo impago: 0.9041188735533465
# Ingreso: 1
# Puntaje: 695
# Capacidad endeudamiento: 70.96
# Monto solicitado: 24.59
# Plazo: 19 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 189
# Año nacimiento: 1977
# Riesgo impago: 0.29840344885082926
# Ingreso: 3
# Puntaje: 903
# Capacidad endeudamiento: 63.84
# Monto solicitado: 15.96
# Plazo: 8 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 190
# Año nacimiento: 1965
# Riesgo impago: 0.32573489168744385
# Ingreso: 0
# Puntaje: 333
# Capacidad endeudamiento: 62.35
# Monto solicitado: 25.26
# Plazo: 36 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 191
# Año nacimiento: 1960
# Riesgo impago: 0.9142450235541646
# Ingreso: 3
# Puntaje: 82
# Capacidad endeudamiento: 87.84
# Monto solicitado: 19.96
# Plazo: 5 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 192
# Año nacimiento: 1970
# Riesgo impago: 0.614183414721239
# Ingreso: 0
# Puntaje: 591
# Capacidad endeudamiento: 84.47
# Monto solicitado: 6.61
# Plazo: 17 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 193
# ...
# Monto solicitado: 2.25
# Plazo: 29 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5494
# Año nacimiento: 1958
# Riesgo impago: 0.07599363317090202
# Ingreso: 0
# Puntaje: 545
# Capacidad endeudamiento: 97.11
# Monto solicitado: 37.57
# Plazo: 4 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5495
# Año nacimiento: 1976
# Riesgo impago: 0.1226343884347566
# Ingreso: 1
# Puntaje: 192
# Capacidad endeudamiento: 32.9
# Monto solicitado: 28.91
# Plazo: 33 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5496
# Año nacimiento: 1979
# Riesgo impago: 0.9847022198046634
# Ingreso: 2
# Puntaje: 182
# Capacidad endeudamiento: 57.47
# Monto solicitado: 4.0
# Plazo: 56 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5497
# Año nacimiento: 1980
# Riesgo impago: 0.3883977985191832
# Ingreso: 1
# Puntaje: 312
# Capacidad endeudamiento: 27.25
# Monto solicitado: 35.21
# Plazo: 25 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5498
# Año nacimiento: 1968
# Riesgo impago: 0.31793048068939855
# Ingreso: 1
# Puntaje: 672
# Capacidad endeudamiento: 44.28
# Monto solicitado: 30.68
# Plazo: 21 meses
#
#
# Tu credito fue aprobado con interés: 6.46%
#
#
# Datos iniciales:
# Nombre persona: Ana 5499
# Año nacimiento: 1999
# Riesgo impago: 0.4935723997101077
# Ingreso: 3
# Puntaje: 204
# Capacidad endeudamiento: 34.36
# Monto solicitado: 39.55
# Plazo: 60 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5500
# Año nacimiento: 1981
# Riesgo impago: 0.8592782177199767
# Ingreso: 2
# Puntaje: 801
# Capacidad endeudamiento: 52.21
# Monto solicitado: 11.09
# Plazo: 50 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5501
# Año nacimiento: 1967
# Riesgo impago: 0.3730253702491044
# Ingreso: 3
# Puntaje: 389
# Capacidad endeudamiento: 28.92
# Monto solicitado: 22.77
# Plazo: 6 meses
#
#
# Tu credito fue aprobado con interés: 7.84%
#
#
# Datos iniciales:
# Nombre persona: Ana 5502
# Año nacimiento: 2000
# Riesgo impago: 0.12084172778616221
# Ingreso: 3
# Puntaje: 110
# Capacidad endeudamiento: 30.97
# Monto solicitado: 11.36
# Plazo: 33 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5503
# Año nacimiento: 1976
# Riesgo impago: 0.4573108417590037
# Ingreso: 1
# Puntaje: 299
# Capacidad endeudamiento: 23.83
# Monto solicitado: 34.38
# Plazo: 30 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5504
# Año nacimiento: 1961
# Riesgo impago: 0.732810190458048
# Ingreso: 1
# Puntaje: 712
# Capacidad endeudamiento: 81.98
# Monto solicitado: 34.62
# Plazo: 47 meses
#
#
# Tu credito fue aprobado con interés: 10.21%
#
#
# Datos iniciales:
# Nombre persona: Ana 5505
# Año nacimiento: 1982
# Riesgo impago: 0.9336859693491726
# Ingreso: 0
# Puntaje: 506
# Capacidad endeudamiento: 95.14
# Monto solicitado: 12.73
# Plazo: 17 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5506
# Año nacimiento: 1973
# Riesgo impago: 0.5953362240447774
# Ingreso: 3
# Puntaje: 628
# Capacidad endeudamiento: 56.64
# Monto solicitado: 17.65
# Plazo: 6 meses
#
#
# Tu credito fue aprobado con interés: 7.67%
#
#
# Datos iniciales:
# Nombre persona: Ana 5507
# Año nacimiento: 1984
# Riesgo impago: 0.13556157037309147
# Ingreso: 3
# Puntaje: 992
# Capacidad endeudamiento: 29.3
# Monto solicitado: 27.41
# Plazo: 52 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 5508
# Año nacimiento: 1971
# Riesgo impago: 0.5477471954856816
# Ingreso: 2
# Puntaje: 5
# Capacidad endeudamiento: 24.9
# Monto solicitado: 10.36
# Plazo: 5 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5509
# Año nacimiento: 1996
# Riesgo impago: 0.014259348391328364
# Ingreso: 1
# Puntaje: 22
# Capacidad endeudamiento: 93.42
# Monto solicitado: 4.53
# Plazo: 58 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5510
# Año nacimiento: 1980
# Riesgo impago: 0.6853855920162393
# Ingreso: 0
# Puntaje: 554
# Capacidad endeudamiento: 30.19
# Monto solicitado: 22.33
# Plazo: 52 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5511
# Año nacimiento: 1982
# Riesgo impago: 0.7682020826338257
# Ingreso: 1
# Puntaje: 66
# Capacidad endeudamiento: 60.99
# Monto solicitado: 9.73
# Plazo: 53 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5512
# Año nacimiento: 1973
# Riesgo impago: 0.597338110777739
# Ingreso: 0
# Puntaje: 851
# Capacidad endeudamiento: 51.51
# Monto solicitado: 29.57
# Plazo: 52 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5513
# Año nacimiento: 1983
# Riesgo impago: 0.4035045750348716
# Ingreso: 3
# Puntaje: 187
# Capacidad endeudamiento: 47.53
# Monto solicitado: 6.37
# Plazo: 23 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5514
# Año nacimiento: 1975
# Riesgo impago: 0.7091775800344523
# Ingreso: 1
# Puntaje: 554
# Capacidad endeudamiento: 93.69
# Monto solicitado: 9.78
# Plazo: 13 meses
#
#
# Tu credito fue aprobado con interés: 11.55%
#
#
# Datos iniciales:
# Nombre persona: Ana 5515
# Año nacimiento: 1960
# Riesgo impago: 0.5477520652662082
# Ingreso: 3
# Puntaje: 809
# Capacidad endeudamiento: 40.24
# Monto solicitado: 34.61
# Plazo: 6 meses
#
#
# Tu credito fue aprobado con interés: 5.39%
#
#
# Datos iniciales:
# Nombre persona: Ana 5516
# Año nacimiento: 1993
# Riesgo impago: 0.20029864336188574
# Ingreso: 0
# Puntaje: 533
# Capacidad endeudamiento: 69.59
# Monto solicitado: 6.32
# Plazo: 17 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5517
# Año nacimiento: 1988
# Riesgo impago: 0.012942731243661965
# Ingreso: 0
# Puntaje: 59
# Capacidad endeudamiento: 73.32
# Monto solicitado: 32.86
# Plazo: 33 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5518
# Año nacimiento: 1982
# Riesgo impago: 0.7162143346339914
# Ingreso: 3
# Puntaje: 122
# Capacidad endeudamiento: 98.76
# Monto solicitado: 15.67
# Plazo: 44 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5519
# Año nacimiento: 1988
# Riesgo impago: 0.20845489751293436
# Ingreso: 2
# Puntaje: 252
# Capacidad endeudamiento: 1.09
# Monto solicitado: 3.28
# Plazo: 25 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5520
# Año nacimiento: 2003
# Riesgo impago: 0.13603760887333682
# Ingreso: 1
# Puntaje: 32
# Capacidad endeudamiento: 73.93
# Monto solicitado: 29.79
# Plazo: 21 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5521
# Año nacimiento: 1997
# Riesgo impago: 0.08440550583534356
# Ingreso: 2
# Puntaje: 392
# Capacidad endeudamiento: 64.16
# Monto solicitado: 16.71
# Plazo: 31 meses
#
#
# Tu credito fue aprobado con interés: 6.92%
#
#
# Datos iniciales:
# Nombre persona: Ana 5522
# Año nacimiento: 1959
# Riesgo impago: 0.025423040303840683
# Ingreso: 0
# Puntaje: 530
# Capacidad endeudamiento: 72.03
# Monto solicitado: 1.49
# Plazo: 3 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5523
# Año nacimiento: 1998
# Riesgo impago: 0.5844679387655115
# Ingreso: 3
# Puntaje: 61
# Capacidad endeudamiento: 98.66
# Monto solicitado: 38.78
# Plazo: 1 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5524
# Año nacimiento: 1969
# Riesgo impago: 0.627205853880511
# Ingreso: 2
# Puntaje: 403
# Capacidad endeudamiento: 41.88
# Monto solicitado: 36.79
# Plazo: 13 meses
#
#
# No pudimos sacar una conclusion, revision manual
#
# Datos iniciales:
# Nombre persona: Ana 5525
# Año nacimiento: 1978
# Riesgo impago: 0.022467063627993222
# Ingreso: 2
# Puntaje: 409
# Capacidad endeudamiento: 95.45
# Monto solicitado: 12.29
# Plazo: 46 meses
#
#
# Tu credito fue aprobado con interés: 6.13%
#
#
# Datos iniciales:
# Nombre persona: Ana 5526
# Año nacimiento: 1981
# Riesgo impago: 0.36746446689007106
# Ingreso: 1
# Puntaje: 927
# Capacidad endeudamiento: 72.42
# Monto solicitado: 22.24
# Plazo: 8 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 5527
# Año nacimiento: 1998
# Riesgo impago: 0.8460706770675308
# Ingreso: 0
# Puntaje: 971
# Capacidad endeudamiento: 29.83
# Monto solicitado: 21.63
# Plazo: 46 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5528
# Año nacimiento: 1973
# Riesgo impago: 0.9177615862438974
# Ingreso: 1
# Puntaje: 427
# Capacidad endeudamiento: 41.42
# Monto solicitado: 28.28
# Plazo: 49 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5529
# Año nacimiento: 1990
# Riesgo impago: 0.8744888241015566
# Ingreso: 2
# Puntaje: 339
# Capacidad endeudamiento: 76.27
# Monto solicitado: 39.71
# Plazo: 53 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5530
# Año nacimiento: 1993
# Riesgo impago: 0.6724032178445125
# Ingreso: 1
# Puntaje: 189
# Capacidad endeudamiento: 29.35
# Monto solicitado: 3.51
# Plazo: 39 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5531
# Año nacimiento: 1964
# Riesgo impago: 0.5416552320635147
# Ingreso: 3
# Puntaje: 75
# Capacidad endeudamiento: 3.43
# Monto solicitado: 39.94
# Plazo: 3 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5532
# Año nacimiento: 2002
# Riesgo impago: 0.5718079450930484
# Ingreso: 3
# Puntaje: 557
# Capacidad endeudamiento: 86.46
# Monto solicitado: 28.73
# Plazo: 15 meses
#
#
# Tu credito fue aprobado con interés: 10.15%
#
#
# Datos iniciales:
# Nombre persona: Ana 5533
# Año nacimiento: 1994
# Riesgo impago: 0.35117456283395077
# Ingreso: 3
# Puntaje: 630
# Capacidad endeudamiento: 85.36
# Monto solicitado: 9.61
# Plazo: 11 meses
#
#
# Tu credito fue aprobado con interés: 5.21%
#
#
# Datos iniciales:
# Nombre persona: Ana 5534
# Año nacimiento: 1973
# Riesgo impago: 0.8777319809911752
# Ingreso: 1
# Puntaje: 530
# Capacidad endeudamiento: 21.25
# Monto solicitado: 31.01
# Plazo: 2 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5535
# Año nacimiento: 2004
# Riesgo impago: 0.9005511349024483
# Ingreso: 2
# Puntaje: 919
# Capacidad endeudamiento: 12.2
# Monto solicitado: 18.46
# Plazo: 19 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5536
# Año nacimiento: 2005
# Riesgo impago: 0.12890466673243894
# Ingreso: 2
# Puntaje: 600
# Capacidad endeudamiento: 18.91
# Monto solicitado: 24.99
# Plazo: 53 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5537
# Año nacimiento: 1960
# Riesgo impago: 0.1585556912064966
# Ingreso: 1
# Puntaje: 151
# Capacidad endeudamiento: 92.51
# Monto solicitado: 16.28
# Plazo: 8 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5538
# Año nacimiento: 1974
# Riesgo impago: 0.967534990449925
# Ingreso: 0
# Puntaje: 910
# Capacidad endeudamiento: 90.61
# Monto solicitado: 34.65
# Plazo: 19 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5539
# Año nacimiento: 1976
# Riesgo impago: 0.15226191729865768
# Ingreso: 2
# Puntaje: 135
# Capacidad endeudamiento: 81.83
# Monto solicitado: 33.19
# Plazo: 27 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5540
# Año nacimiento: 2000
# Riesgo impago: 0.5754580199530983
# Ingreso: 2
# Puntaje: 51
# Capacidad endeudamiento: 26.14
# Monto solicitado: 3.94
# Plazo: 54 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5541
# Año nacimiento: 1981
# Riesgo impago: 0.2599966464165696
# Ingreso: 1
# Puntaje: 353
# Capacidad endeudamiento: 3.05
# Monto solicitado: 23.11
# Plazo: 23 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5542
# Año nacimiento: 1997
# Riesgo impago: 0.7146474081585713
# Ingreso: 2
# Puntaje: 18
# Capacidad endeudamiento: 32.71
# Monto solicitado: 30.25
# Plazo: 18 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5543
# Año nacimiento: 1956
# Riesgo impago: 0.5622493139849053
# Ingreso: 2
# Puntaje: 362
# Capacidad endeudamiento: 65.46
# Monto solicitado: 12.62
# Plazo: 58 meses
#
#
# No pudimos sacar una conclusion, revision manual
#
# Datos iniciales:
# Nombre persona: Ana 5544
# Año nacimiento: 1968
# Riesgo impago: 0.4786700008472885
# Ingreso: 1
# Puntaje: 175
# Capacidad endeudamiento: 27.73
# Monto solicitado: 21.2
# Plazo: 10 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5545
# Año nacimiento: 1982
# Riesgo impago: 0.19184866661173672
# Ingreso: 0
# Puntaje: 990
# Capacidad endeudamiento: 12.47
# Monto solicitado: 23.8
# Plazo: 32 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5546
# Año nacimiento: 1987
# Riesgo impago: 0.05450195996553875
# Ingreso: 0
# Puntaje: 534
# Capacidad endeudamiento: 28.96
# Monto solicitado: 38.16
# Plazo: 52 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5547
# Año nacimiento: 1990
# Riesgo impago: 0.8605588506175091
# Ingreso: 0
# Puntaje: 283
# Capacidad endeudamiento: 98.29
# Monto solicitado: 15.81
# Plazo: 48 meses
#
#
# Tu credito no fue aprobado
# Razon: Riesgo muy alto
#
# Datos iniciales:
# Nombre persona: Ana 5548
# Año nacimiento: 1963
# Riesgo impago: 0.09497083794700334
# Ingreso: 3
# Puntaje: 89
# Capacidad endeudamiento: 22.71
# Monto solicitado: 33.6
# Plazo: 6 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5549
# Año nacimiento: 1980
# Riesgo impago: 0.4014524193021114
# Ingreso: 1
# Puntaje: 666
# Capacidad endeudamiento: 75.84
# Monto solicitado: 4.6
# Plazo: 14 meses
#
#
# Tu credito fue aprobado con interés: 5.85%
#
#
# Datos iniciales:
# Nombre persona: Ana 5550
# Año nacimiento: 1958
# Riesgo impago: 0.6953201238767783
# Ingreso: 3
# Puntaje: 11
# Capacidad endeudamiento: 75.26
# Monto solicitado: 6.7
# Plazo: 21 meses
#
#
# Tu credito no fue aprobado
# Razon: Historial crediticio muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5551
# Año nacimiento: 2004
# Riesgo impago: 0.3908167271954146
# Ingreso: 3
# Puntaje: 243
# Capacidad endeudamiento: 13.38
# Monto solicitado: 31.67
# Plazo: 51 meses
#
#
# Tu credito no fue aprobado
# Razon: Monto excede la capacidad de endeudamiento
#
# Datos iniciales:
# Nombre persona: Ana 5552
# Año nacimiento: 1984
# Riesgo impago: 0.10376314459915748
# Ingreso: 2
# Puntaje: 992
# Capacidad endeudamiento: 8.55
# Monto solicitado: 4.01
# Plazo: 49 meses
#
#
# Tu credito fue aprobado con interés: 5%
#
#
# Datos iniciales:
# Nombre persona: Ana 5553
# Año nacimiento: 2000
# Riesgo impago: 0.41170618239298273
# Ingreso: 0
# Puntaje: 582
# Capacidad endeudamiento: 63.05
# Monto solicitado: 22.35
# Plazo: 24 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5554
# Año nacimiento: 1980
# Riesgo impago: 0.4356715837760283
# Ingreso: 0
# Puntaje: 957
# Capacidad endeudamiento: 40.04
# Monto solicitado: 13.84
# Plazo: 31 meses
#
#
# Tu credito no fue aprobado
# Razon: Sueldo muy bajo
#
# Datos iniciales:
# Nombre persona: Ana 5555
# Año nacimiento: 1983
# Riesgo impago: 0.857150734335133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 226
#     224 print(f"Año nacimiento: {anio_nacimiento}")
#     225 print(f"Riesgo impago: {riesgo_impago}")
# --> 226 print(f"Ingreso: {ingreso}")
#     227 print(f"Puntaje: {puntaje}")
#     228 print(f"Capacidad endeudamiento: {capacidad_endeudamiento}")
#
# KeyboardInterrupt:
